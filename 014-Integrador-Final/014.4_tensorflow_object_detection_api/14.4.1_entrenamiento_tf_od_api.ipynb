# %%
# Configura la variable de entorno PYTHONPATH para este cuaderno
import os
from tensorflow import keras
import tensorflow as tf

# Asegúrate de que esta ruta sea la misma donde clonaste 'tensorflow/models/research'
research_dir = '/home/garzamorada/tensorflow/models/research'
os.environ['PYTHONPATH'] = f'{research_dir}:{research_dir}/slim:' + os.environ.get('PYTHONPATH', '')

# Verificación de GPU (opcional, pero buena práctica)
print("Dispositivos GPU detectados:", tf.config.list_physical_devices('GPU'))
if not tf.config.list_physical_devices('GPU'):
    print("¡Advertencia! No se detectó ninguna GPU. El entrenamiento se ejecutará en CPU (mucho más lento).")

# Rutas a tu archivo de configuración y al directorio de salida del entrenamiento
pipeline_config_path = '/home/garzamorada/my_character_detector_workspace/models/pipeline.config'
model_dir = '/home/garzamorada/my_character_detector_workspace/training'

# Comando de entrenamiento
# Asegúrate de que el script model_main_tf2.py sea accesible desde research_dir
train_command = f"python {research_dir}/object_detection/model_main_tf2.py --pipeline_config_path={pipeline_config_path} --model_dir={model_dir} --alsologtostderr"

print(f"\nEjecutando comando de entrenamiento:\n{train_command}\n")
# Usa '!' para ejecutar el comando de shell directamente en Jupyter
# !{train_command}
# Out:
# Dispositivos GPU detectados: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# Ejecutando comando de entrenamiento:
# python /home/garzamorada/tensorflow/models/research/object_detection/model_main_tf2.py --pipeline_config_path=/home/garzamorada/my_character_detector_workspace/models/pipeline.config --model_dir=/home/garzamorada/my_character_detector_workspace/training --alsologtostderr
#
# 2025-06-22 15:59:52.444077: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# /home/garzamorada/anaconda3/envs/gpu_env/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/garzamorada/anaconda3/envs/gpu_env/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# ...

# %%
# !python /home/garzamorada/tensorflow/models/research/object_detection/exporter_main_v2.py \
    --input_type=image_tensor \
    --pipeline_config_path=/home/garzamorada/my_character_detector_workspace/models/pipeline.config \
    --trained_checkpoint_dir=/home/garzamorada/my_character_detector_workspace/training \
    --output_directory=/home/garzamorada/my_character_detector_workspace/exported_model
# Out:
# 2025-06-22 16:57:29.892136: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# /home/garzamorada/anaconda3/envs/gpu_env/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/garzamorada/anaconda3/envs/gpu_env/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/garzamorada/anaconda3/envs/gpu_env/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutex6unlockEv']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...
