# %% [markdown]
# # Detector de Texto para OCR
# Este modelo pretende detectar la resencia de texto en una imagen y en lo posible retornar las lineas de texto y cajas de los carcteres que las componen.
#
# Modelo basado en yolo 8

# %% [markdown]
# ## Importación de Librerias

# %%
#!pip install -q ultralytics
from ultralytics import YOLO

# %%
#Importo librerias a utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import cv2
import random
from PIL import Image, ImageFilter, ImageDraw, ImageFont
from IPython.display import Image as ImageDisplay
from IPython.core.display import HTML
from io import BytesIO
import base64
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Generacion de imagenes

# %%
#Descomprimo las fuentes

#!unzip c:/tmp/content/fuentes.zip -d c:/tmp/content/
# Out:
# "unzip" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %% [markdown]
# ## Funciones auxiliares

# %%
# Funciones auxiliares
def np_to_base64_img(arr):
    """Convierte un np.array a una imagen embebida en base64"""
    h,w = arr.shape[:2]
    im = Image.fromarray(arr)
    buffer = BytesIO()
    im.save(buffer, format="PNG")
    img_str = base64.b64encode(buffer.getvalue()).decode()
    return f'<img src="data:image/png;base64,{img_str}" width="{w}" height="{h}"/>'

# %%
def get_bbox_from_image(image_array):
    """
    Toma un array NumPy de una imagen en escala de grises, encuentra los contornos,
    los combina y devuelve las coordenadas de la bounding box en formato
    (x_min, y_min, x_max, y_max).

    Args:
        image_array (np.ndarray): Una imagen en escala de grises como un array NumPy.

    Returns:
        tuple: Una tupla (x_min, y_min, x_max, y_max) que representa la bounding box.
               Retorna None si no se encuentran contornos.
    """
    # Asegurarse de que la imagen esté en escala de grises si no lo está ya
    if len(image_array.shape) == 3:
        gray_image = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)
    else:
        gray_image = image_array

    # Binarizar la imagen si es necesario para asegurar buenos contornos
    # Esto es crucial si la imagen de entrada tiene tonos de gris en lugar de solo blanco/negro
    # Ajusta el umbral (e.g., 127) y el tipo (e.g., cv2.THRESH_BINARY_INV) según tus imágenes.
    _, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)


    # Encontrar contornos
    # cv2.RETR_EXTERNAL recupera solo los contornos externos (útil para caracteres con agujeros internos)
    contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if not contours:
        binary_image=cv2.bitwise_not(binary_image)
        contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if not contours:
            return None # No se encontraron contornos

    # Combinar todos los contornos en uno solo (para caracteres con múltiples partes como 'i' o 'j')
    # Solo apilamos si hay contornos válidos (size > 0)
    valid_contours = [c.squeeze() for c in contours if c.size > 0]
    if not valid_contours:
        return None # No se encontraron contornos válidos después de limpiar

    all_points = np.vstack(valid_contours)

    # Encontrar el rectángulo delimitador para el contorno combinado
    x, y, w, h = cv2.boundingRect(all_points)

    # Retornar en el formato (x_min, y_min, x_max, y_max)
    x_min, y_min = x, y
    x_max, y_max = x + w, y + h

    return (x_min, y_min, x_max, y_max)

# %%
def generate_combinations(char_list_original, min_len=3, max_len=7):

    # 1. Convertir la cadena original a una lista y desordenarla una única vez
    shuffled_char_pool = list(char_list_original)
    random.shuffle(shuffled_char_pool)

    generated_combinations = []

    pool_index = 0
    total_pool_len = len(shuffled_char_pool)

    while pool_index < total_pool_len:
        # Calcular cuántos caracteres quedan en el pool
        remaining_chars = total_pool_len - pool_index

        # Determinar la longitud de la combinación actual
        # Si quedan 7 o menos caracteres (o menos de max_len) y al menos min_len, usa todos los restantes.
        # De lo contrario, elige una longitud aleatoria entre min_len y max_len.
        if remaining_chars <= max_len:
            current_len = remaining_chars
        else:
            current_len = random.randint(min_len, max_len)
            # Asegurarse de que la longitud elegida no exceda los caracteres restantes
            current_len = min(current_len, remaining_chars)

        # Extraer la combinación del pool
        combination_chars = shuffled_char_pool[pool_index : pool_index + current_len]
        combination = "".join(combination_chars)

        generated_combinations.append(combination)
        pool_index += current_len # Mover el índice al siguiente punto en el pool

    print(f"Número de combinaciones generadas: {len(generated_combinations)}")
    return generated_combinations

# %% [markdown]
# ## Generacion del dataset

# %%
#Creo un dataset con las fuentes
def create_font_dataset(base_folder):
    """
    Crea un DataFrame de Pandas con información sobre las fuentes TTF encontradas.

    Args:
        base_folder (str): Ruta a la carpeta principal que contiene las subcarpetas de tipos de letra.

    Returns:
        pd.DataFrame: DataFrame con columnas 'font_name' y 'font_path'.
    """
    font_data = []
    print(f"Buscando archivos .ttf en: {base_folder}")
    for font_type_folder in os.listdir(base_folder):
        font_type_path = os.path.join(base_folder, font_type_folder)
        if not os.path.isdir(font_type_path):
            continue

        ttf_files = [f for f in os.listdir(font_type_path) if f.lower().endswith('.ttf')]

        if not ttf_files:
            print(f"Advertencia: No se encontraron archivos .ttf en '{font_type_path}'. Saltando.")
            continue

        # Asumimos un único archivo .ttf por carpeta de tipo de letra o elegimos el primero
        font_file_name = ttf_files[0]
        full_font_path = os.path.join(font_type_path, font_file_name)

        font_data.append({
            'font_name': font_type_folder, # Usamos el nombre de la carpeta como nombre de la fuente
            'font_path': full_font_path
        })

    return pd.DataFrame(font_data)

# %%
# prompt: quiero una funcion que reciba una imagen de cv en escala de grises y le aplique blur gausieano y la devuelva en el mismo formato

def apply_gaussian_blur(image_gray, ksize=(5, 5), sigmaX=0):
    """
    Aplica un filtro de desenfoque Gaussiano a una imagen en escala de grises.

    Args:
        image_gray (np.ndarray): Imagen de entrada en escala de grises (array NumPy).
        ksize (tuple): Tamaño del kernel Gaussiano. Debe ser una tupla de números
                       enteros impares positivos (ancho, alto).
        sigmaX (float): Desviación estándar del kernel en la dirección X. Si es 0,
                        se calcula automáticamente en función del tamaño del kernel.

    Returns:
        np.ndarray: La imagen desenfocada como un array NumPy en escala de grises.
    """
    if len(image_gray.shape) != 2:
        print("Advertencia: La imagen de entrada no está en escala de grises. Intentando convertir.")
        image_gray = cv2.cvtColor(image_gray, cv2.COLOR_BGR2GRAY)

    blurred_image = cv2.GaussianBlur(image_gray, ksize, sigmaX)
    return blurred_image

# %%
# prompt: quiero una funcion que reciba una imagen de opencv en escala de grises y la rote 5 o -5 grados y devuelva en el mismo formato

def rotate_image(image_gray, angle, color=(0, 0, 0)):
    if len(image_gray.shape) != 2:
        print("Advertencia: La imagen de entrada no está en escala de grises. Intentando convertir.")
        image_gray = cv2.cvtColor(image_gray, cv2.COLOR_BGR2GRAY)

    (h, w) = image_gray.shape[:2]
    center = (w // 2, h // 2)

    # Calcular la matriz de rotación
    M = cv2.getRotationMatrix2D(center, angle, 1.0)

    # Calcular las nuevas dimensiones de la imagen para evitar recortes
    cos = np.abs(M[0, 0])
    sin = np.abs(M[0, 1])
    nW = int((h * sin) + (w * cos))
    nH = int((h * cos) + (w * sin))

    # Ajustar la matriz de translación para que el centro permanezca en el centro de la nueva imagen
    M[0, 2] += (nW / 2) - center[0]
    M[1, 2] += (nH / 2) - center[1]

    # Realizar la rotación, manteniendo el fondo negro (0)
    rotated_image = cv2.warpAffine(image_gray, M, (nW, nH), borderValue=color)

    return rotated_image

# %%
def create_noise_background(image_shape, gray_center=128, noise_amplitude=50):
    """
    Crea un fondo de ruido aleatorio predominantemente gris, con cierta variación.

    Args:
        image_shape (tuple): Las dimensiones (altura, anchura) de la imagen.
        gray_center (int): El valor central de gris para el ruido (0-255).
        noise_amplitude (int): La amplitud del ruido alrededor del centro.
                               Por ejemplo, 50 significa ruido entre [centro-50, centro+50].

    Returns:
        np.ndarray: Un array NumPy que representa el fondo de ruido.
    """
    # Genera ruido en un rango limitado alrededor del centro
    # np.random.normal para un ruido más natural (gaussiano) o randint para uniforme.
    # Usaremos randint para simplificar y controlar el rango.

    # Calcular el rango min y max para el ruido
    min_val = max(0, gray_center - noise_amplitude)
    max_val = min(255, gray_center + noise_amplitude)

    # Genera el ruido y lo escala al rango deseado
    noise = np.random.randint(min_val, max_val + 1, image_shape, dtype=np.uint8)
    return noise

def get_bbox_from_image_array(image_array):
    """
    Toma un array NumPy de una imagen en escala de grises, encuentra los contornos,
    los combina y devuelve las coordenadas de la bounding box en formato
    (x_min, y_min, x_max, y_max).

    Args:
        image_array (np.ndarray): Una imagen en escala de grises como un array NumPy.

    Returns:
        tuple: Una tupla (x_min, y_min, x_max, y_max) que representa la bounding box.
               Retorna None si no se encuentran contornos.
    """
    # Asegurarse de que la imagen esté en escala de grises si no lo está ya
    if len(image_array.shape) == 3:
        gray_image = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)
    else:
        gray_image = image_array

    # Binarizar la imagen si es necesario para asegurar buenos contornos
    # Esto es crucial si la imagen de entrada tiene tonos de gris en lugar de solo blanco/negro
    # Ajusta el umbral (e.g., 127) y el tipo (e.g., cv2.THRESH_BINARY_INV) según tus imágenes.
    _, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)


    # Encontrar contornos
    # cv2.RETR_EXTERNAL recupera solo los contornos externos (útil para caracteres con agujeros internos)
    contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if not contours:
        binary_image=cv2.bitwise_not(binary_image)
        contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if not contours:
            return None # No se encontraron contornos

    # Combinar todos los contornos en uno solo (para caracteres con múltiples partes como 'i' o 'j')
    # Solo apilamos si hay contornos válidos (size > 0)
    valid_contours = [c.squeeze() for c in contours if c.size > 0]
    if not valid_contours:
        return None # No se encontraron contornos válidos después de limpiar

    all_points = np.vstack(valid_contours)

    # Encontrar el rectángulo delimitador para el contorno combinado
    x, y, w, h = cv2.boundingRect(all_points)

    # Retornar en el formato (x_min, y_min, x_max, y_max)
    x_min, y_min = x, y
    x_max, y_max = x + w, y + h

    return (x_min, y_min, x_max, y_max)


# --- Generación de Imagen Base y Bbox (con Pillow) ---
def generate_base_char_image_and_bbox(char, font_path, font_size=200, img_size=(256, 256)):
    """
    Genera la imagen base de un caracter (blanco sobre fondo negro) usando Pillow
    y calcula su bounding box.
    """
    try:
        font = ImageFont.truetype(font_path, font_size)
    except IOError:
        print(f"Advertencia: No se pudo cargar la fuente {font_path}. Retornando None.")
        return None, None
    except Exception as e:
        print(f"Error al cargar la fuente {font_path}: {e}. Retornando None.")
        return None, None

    img_black_bg_white_char_pil = Image.new('L', img_size, color=0)
    draw = ImageDraw.Draw(img_black_bg_white_char_pil)

    try:
        # textbbox returns (left, top, right, bottom) of the text
        text_bbox = draw.textbbox((0,0), char, font=font)
    except Exception as e:
        print(f"Error al obtener textbbox para '{char}' con {font_path}: {e}. Retornando None.")
        return None, None

    text_width = text_bbox[2] - text_bbox[0]
    text_height = text_bbox[3] - text_bbox[1]

    # Calculate position to center the text
    # x_center: (image_width - text_width) / 2 - text_bbox[0]
    # y_center: (image_height - text_height) / 2 - text_bbox[1]
    # These calculations adjust for the actual content's bbox offset
    x_center = (img_size[0] - text_width) / 2 - text_bbox[0]
    y_center = (img_size[1] - text_height) / 2 - text_bbox[1]

    draw.text((x_center, y_center), char, font=font, fill=255)
    img_np = np.array(img_black_bg_white_char_pil)

    bbox = get_bbox_from_image_array(img_np)

    return img_np, bbox

    # Crear imagen con caracter blanco sobre fondo negro
    img_black_bg_white_char_pil = Image.new('L', img_size, color=0) # Fondo negro
    draw = ImageDraw.Draw(img_black_bg_white_char_pil)

    # Calcular posición para centrar el texto
    # Usar textbbox para obtener dimensiones del texto renderizado
    try:
        text_bbox = draw.textbbox((0,0), char, font=font)
    except Exception as e:
        print(f"Error al obtener textbbox para '{char}' con {font_path}: {e}. Retornando None.")
        return None, None

    text_width = text_bbox[2] - text_bbox[0]
    text_height = text_bbox[3] - text_bbox[1]
    x_center = (img_size[0] - text_width) / 2 - text_bbox[0]
    y_center = (img_size[1] - text_height) / 2 - text_bbox[1]

    draw.text((x_center, y_center), char, font=font, fill=255) # Caracter blanco
    img_np = np.array(img_black_bg_white_char_pil) # Convertir a NumPy array

    # Calcular bbox usando la función de OpenCV
    bbox = get_bbox_from_image_array(img_np)

    return img_np, bbox

def generate_variations_from_base(base_image_np, bbox):
    """
    Genera las 5 variaciones adicionales de una imagen de caracter
    a partir de una imagen base (caracter blanco sobre fondo negro).
    """
    variations = []

    # --- Variaciones con blur ---
    img_blur_black = base_image_np.copy()
    img_blur_black = apply_gaussian_blur(img_blur_black)
    variations.append((img_blur_black.copy(), "blur", "blanco"))


    # --- Variaciones con rotacion ---
    img_rotate_black_1 = base_image_np.copy()
    img_rotate_black_1 = rotate_image(img_rotate_black_1, 5, (0, 0, 0))
    img_rotate_black_1 = cv2.resize(img_rotate_black_1, (base_image_np.shape[1], base_image_np.shape[0]))
    variations.append((img_rotate_black_1, "rotate", "blanco"))
    img_rotate_black_2 = base_image_np.copy()
    img_rotate_black_2 = rotate_image(img_rotate_black_2, -5, (0, 0, 0))
    img_rotate_black_2 = cv2.resize(img_rotate_black_2, (base_image_np.shape[1], base_image_np.shape[0]))
    variations.append((img_rotate_black_2, "rotate", "blanco"))

    return variations

# %%
# --- Función para generar los datasets principales ---
def generate_full_datasets(font_df):
    """
    Genera el dataset de NumPy y Pandas a partir de las fuentes TTF.

    Args:
        font_df: dataset de fuentes.

    Returns:
        tuple: (numpy_dataset, pandas_dataset)
    """

    numpy_data_list = []
    pandas_data = []
    global_index = 0

    # Caracteres a generar
    characters_to_generate = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789"

    if font_df.empty:
        print("No se encontraron fuentes para procesar.")
        return np.array([], dtype=[('image', object), ('bbox', object), ('index', int)]), pd.DataFrame()

    for index, font_row in font_df.iterrows():
        font_name = font_row['font_name']
        font_path = font_row['font_path']
        print(f"Generando caracteres para la fuente: {font_name} ({font_path})")

        for char in characters_to_generate:
            # Generar la imagen base (carácter blanco sobre fondo negro) y su bbox con Pillow
            base_image_np, bbox = generate_base_char_image_and_bbox(char, font_path)

            if base_image_np is None or bbox is None:
                print(f"Saltando '{char}' de '{font_name}' debido a un error en la generación de la imagen base o bbox.")
                continue

            # La imagen base se añade al dataset de NumPy
            numpy_data_list.append((base_image_np, bbox, global_index))
            pandas_data.append({
                'index': global_index,
                'character': char,
                'font_type': font_name,
                'background_type': "negro", # La base siempre es blanco sobre negro
                'character_color': "blanco"
            })
            global_index += 1

            # Generar las otras 5 variaciones usando OpenCV/NumPy
            other_variations = generate_variations_from_base(base_image_np, bbox)

            for img_var, bg_type, char_color in other_variations:
                if bg_type == 'rotate' and char_color == 'blanco':
                    bbox = get_bbox_from_image_array(img_var)
                elif bg_type == 'rotate' and char_color == 'negro':
                    bbox = get_bbox_from_image_array(cv2.bitwise_not(img_var.copy()))
                numpy_data_list.append((img_var, bbox, global_index))
                pandas_data.append({
                    'index': global_index,
                    'character': char,
                    'font_type': font_name,
                    'background_type': bg_type,
                    'character_color': char_color
                })
                global_index += 1

    numpy_dataset = np.array(numpy_data_list, dtype=[('image', object), ('bbox', object), ('index', int)])
    pandas_dataset = pd.DataFrame(pandas_data)

    return numpy_dataset, pandas_dataset

# %%
# Generar los datasets
font_df = create_font_dataset('c:/tmp/content/ocr_fonts_latin')
numpy_dataset, pandas_dataset = generate_full_datasets(font_df)

print("\nGeneración de datasets completada.")
print("\nDataset de NumPy (estructura):")
print(numpy_dataset.dtype)
print(f"Número total de entradas en NumPy dataset: {len(numpy_dataset)}")

print("\nDataset de Pandas (primeras 5 filas):")
print(pandas_dataset.head())
print(f"Número total de entradas en Pandas dataset: {len(pandas_dataset)}")
# Out:
# Buscando archivos .ttf en: c:/tmp/content/ocr_fonts_latin
# Generando caracteres para la fuente: ABeeZee (c:/tmp/content/ocr_fonts_latin\ABeeZee\ABeeZee-italic.ttf)
# Generando caracteres para la fuente: Abhaya_Libre (c:/tmp/content/ocr_fonts_latin\Abhaya_Libre\Abhaya_Libre-500.ttf)
# Generando caracteres para la fuente: Aboreto (c:/tmp/content/ocr_fonts_latin\Aboreto\Aboreto-regular.ttf)
# Generando caracteres para la fuente: Abril_Fatface (c:/tmp/content/ocr_fonts_latin\Abril_Fatface\Abril_Fatface-regular.ttf)
# Generando caracteres para la fuente: Abyssinica_SIL (c:/tmp/content/ocr_fonts_latin\Abyssinica_SIL\Abyssinica_SIL-regular.ttf)
# Generando caracteres para la fuente: Aclonica (c:/tmp/content/ocr_fonts_latin\Aclonica\Aclonica-regular.ttf)
# Generando caracteres para la fuente: ADLaM_Display (c:/tmp/content/ocr_fonts_latin\ADLaM_Display\ADLaM_Display-regular.ttf)
# Generando caracteres para la fuente: Advent_Pro (c:/tmp/content/ocr_fonts_latin\Advent_Pro\Advent_Pro-100.ttf)
# Generando caracteres para la fuente: Afacad (c:/tmp/content/ocr_fonts_latin\Afacad\Afacad-500.ttf)
# Generando caracteres para la fuente: Afacad_Flux (c:/tmp/content/ocr_fonts_latin\Afacad_Flux\Afacad_Flux-100.ttf)
# Generando caracteres para la fuente: Agbalumo (c:/tmp/content/ocr_fonts_latin\Agbalumo\Agbalumo-regular.ttf)
# Generando caracteres para la fuente: Agdasima (c:/tmp/content/ocr_fonts_latin\Agdasima\Agdasima-700.ttf)
# Generando caracteres para la fuente: Aguafina_Script (c:/tmp/content/ocr_fonts_latin\Aguafina_Script\Aguafina_Script-regular.ttf)
# Generando caracteres para la fuente: Agu_Display (c:/tmp/content/ocr_fonts_latin\Agu_Display\Agu_Display-regular.ttf)
# Generando caracteres para la fuente: Akatab (c:/tmp/content/ocr_fonts_latin\Akatab\Akatab-500.ttf)
# Generando caracteres para la fuente: Akaya_Kanadaka (c:/tmp/content/ocr_fonts_latin\Akaya_Kanadaka\Akaya_Kanadaka-regular.ttf)
# Generando caracteres para la fuente: Akaya_Telivigala (c:/tmp/content/ocr_fonts_latin\Akaya_Telivigala\Akaya_Telivigala-regular.ttf)
# Generando caracteres para la fuente: Akronim (c:/tmp/content/ocr_fonts_latin\Akronim\Akronim-regular.ttf)
# Generando caracteres para la fuente: Akshar (c:/tmp/content/ocr_fonts_latin\Akshar\Akshar-300.ttf)
# Generando caracteres para la fuente: Aladin (c:/tmp/content/ocr_fonts_latin\Aladin\Aladin-regular.ttf)
# Generando caracteres para la fuente: Alata (c:/tmp/content/ocr_fonts_latin\Alata\Alata-regular.ttf)
# Generando caracteres para la fuente: Alatsi (c:/tmp/content/ocr_fonts_latin\Alatsi\Alatsi-regular.ttf)
# Generando caracteres para la fuente: Albert_Sans (c:/tmp/content/ocr_fonts_latin\Albert_Sans\Albert_Sans-100.ttf)
# Generando caracteres para la fuente: Alegreya (c:/tmp/content/ocr_fonts_latin\Alegreya\Alegreya-500.ttf)
# Generando caracteres para la fuente: Alegreya_Sans (c:/tmp/content/ocr_fonts_latin\Alegreya_Sans\Alegreya_Sans-100.ttf)
# Generando caracteres para la fuente: Alegreya_Sans_SC (c:/tmp/content/ocr_fonts_latin\Alegreya_Sans_SC\Alegreya_Sans_SC-100.ttf)
# Generando caracteres para la fuente: Alegreya_SC (c:/tmp/content/ocr_fonts_latin\Alegreya_SC\Alegreya_SC-500.ttf)
# Generando caracteres para la fuente: Aleo (c:/tmp/content/ocr_fonts_latin\Aleo\Aleo-100.ttf)
# Generando caracteres para la fuente: Alexandria (c:/tmp/content/ocr_fonts_latin\Alexandria\Alexandria-100.ttf)
# Generando caracteres para la fuente: Alex_Brush (c:/tmp/content/ocr_fonts_latin\Alex_Brush\Alex_Brush-regular.ttf)
# Generando caracteres para la fuente: Alfa_Slab_One (c:/tmp/content/ocr_fonts_latin\Alfa_Slab_One\AlfaSlabOne-Regular.ttf)
# Generando caracteres para la fuente: Alice (c:/tmp/content/ocr_fonts_latin\Alice\Alice-regular.ttf)
# Generando caracteres para la fuente: Alike (c:/tmp/content/ocr_fonts_latin\Alike\Alike-regular.ttf)
# Generando caracteres para la fuente: Alike_Angular (c:/tmp/content/ocr_fonts_latin\Alike_Angular\Alike_Angular-regular.ttf)
# Generando caracteres para la fuente: Alkalami (c:/tmp/content/ocr_fonts_latin\Alkalami\Alkalami-regular.ttf)
# Generando caracteres para la fuente: Alkatra (c:/tmp/content/ocr_fonts_latin\Alkatra\Alkatra-500.ttf)
# Generando caracteres para la fuente: Allan (c:/tmp/content/ocr_fonts_latin\Allan\Allan-700.ttf)
# Generando caracteres para la fuente: Allison (c:/tmp/content/ocr_fonts_latin\Allison\Allison-regular.ttf)
# Generando caracteres para la fuente: Allura (c:/tmp/content/ocr_fonts_latin\Allura\Allura-regular.ttf)
# Generando caracteres para la fuente: Almendra (c:/tmp/content/ocr_fonts_latin\Almendra\Almendra-700.ttf)
# Generando caracteres para la fuente: Almendra_Display (c:/tmp/content/ocr_fonts_latin\Almendra_Display\Almendra_Display-regular.ttf)
# Generando caracteres para la fuente: Alumni_Sans (c:/tmp/content/ocr_fonts_latin\Alumni_Sans\Alumni_Sans-100.ttf)
# Generando caracteres para la fuente: Alumni_Sans_Collegiate_One (c:/tmp/content/ocr_fonts_latin\Alumni_Sans_Collegiate_One\Alumni_Sans_Collegiate_One-italic.ttf)
# Generando caracteres para la fuente: Alumni_Sans_Inline_One (c:/tmp/content/ocr_fonts_latin\Alumni_Sans_Inline_One\Alumni_Sans_Inline_One-italic.ttf)
# Generando caracteres para la fuente: Alumni_Sans_Pinstripe (c:/tmp/content/ocr_fonts_latin\Alumni_Sans_Pinstripe\Alumni_Sans_Pinstripe-italic.ttf)
# Generando caracteres para la fuente: Alumni_Sans_SC (c:/tmp/content/ocr_fonts_latin\Alumni_Sans_SC\Alumni_Sans_SC-100.ttf)
# Generando caracteres para la fuente: Amarante (c:/tmp/content/ocr_fonts_latin\Amarante\Amarante-regular.ttf)
# Generando caracteres para la fuente: Amatic_SC (c:/tmp/content/ocr_fonts_latin\Amatic_SC\Amatic_SC-700.ttf)
# Generando caracteres para la fuente: Amiko (c:/tmp/content/ocr_fonts_latin\Amiko\Amiko-600.ttf)
# Generando caracteres para la fuente: Amiri (c:/tmp/content/ocr_fonts_latin\Amiri\Amiri-700.ttf)
# Generando caracteres para la fuente: Amita (c:/tmp/content/ocr_fonts_latin\Amita\Amita-700.ttf)
# Generando caracteres para la fuente: Anaheim (c:/tmp/content/ocr_fonts_latin\Anaheim\Anaheim-500.ttf)
# Generando caracteres para la fuente: Ancizar_Sans (c:/tmp/content/ocr_fonts_latin\Ancizar_Sans\Ancizar_Sans-100.ttf)
# Generando caracteres para la fuente: Ancizar_Serif (c:/tmp/content/ocr_fonts_latin\Ancizar_Serif\Ancizar_Serif-300.ttf)
# Generando caracteres para la fuente: Andada_Pro (c:/tmp/content/ocr_fonts_latin\Andada_Pro\Andada_Pro-500.ttf)
# Generando caracteres para la fuente: Andika (c:/tmp/content/ocr_fonts_latin\Andika\Andika-700.ttf)
# Generando caracteres para la fuente: Anek_Bangla (c:/tmp/content/ocr_fonts_latin\Anek_Bangla\Anek_Bangla-100.ttf)
# Generando caracteres para la fuente: Anek_Devanagari (c:/tmp/content/ocr_fonts_latin\Anek_Devanagari\Anek_Devanagari-100.ttf)
# Generando caracteres para la fuente: Anek_Gujarati (c:/tmp/content/ocr_fonts_latin\Anek_Gujarati\Anek_Gujarati-100.ttf)
# Generando caracteres para la fuente: Anek_Gurmukhi (c:/tmp/content/ocr_fonts_latin\Anek_Gurmukhi\Anek_Gurmukhi-100.ttf)
# Generando caracteres para la fuente: Anek_Kannada (c:/tmp/content/ocr_fonts_latin\Anek_Kannada\Anek_Kannada-100.ttf)
# Generando caracteres para la fuente: Anek_Latin (c:/tmp/content/ocr_fonts_latin\Anek_Latin\Anek_Latin-100.ttf)
# Generando caracteres para la fuente: Anek_Malayalam (c:/tmp/content/ocr_fonts_latin\Anek_Malayalam\Anek_Malayalam-100.ttf)
# Generando caracteres para la fuente: Anek_Odia (c:/tmp/content/ocr_fonts_latin\Anek_Odia\Anek_Odia-100.ttf)
# Generando caracteres para la fuente: Anek_Tamil (c:/tmp/content/ocr_fonts_latin\Anek_Tamil\Anek_Tamil-100.ttf)
# Generando caracteres para la fuente: Anek_Telugu (c:/tmp/content/ocr_fonts_latin\Anek_Telugu\Anek_Telugu-100.ttf)
# Generando caracteres para la fuente: Annapurna_SIL (c:/tmp/content/ocr_fonts_latin\Annapurna_SIL\Annapurna_SIL-700.ttf)
# Generando caracteres para la fuente: Annie_Use_Your_Telescope (c:/tmp/content/ocr_fonts_latin\Annie_Use_Your_Telescope\Annie_Use_Your_Telescope-regular.ttf)
# Generando caracteres para la fuente: Anonymous_Pro (c:/tmp/content/ocr_fonts_latin\Anonymous_Pro\Anonymous_Pro-700.ttf)
# Generando caracteres para la fuente: Anta (c:/tmp/content/ocr_fonts_latin\Anta\Anta-regular.ttf)
# Generando caracteres para la fuente: Anton (c:/tmp/content/ocr_fonts_latin\Anton\Anton-regular.ttf)
# Generando caracteres para la fuente: Antonio (c:/tmp/content/ocr_fonts_latin\Antonio\Antonio-100.ttf)
# Generando caracteres para la fuente: Anton_SC (c:/tmp/content/ocr_fonts_latin\Anton_SC\Anton_SC-regular.ttf)
# Generando caracteres para la fuente: Anuphan (c:/tmp/content/ocr_fonts_latin\Anuphan\Anuphan-100.ttf)
# Generando caracteres para la fuente: Anybody (c:/tmp/content/ocr_fonts_latin\Anybody\Anybody-100.ttf)
# Generando caracteres para la fuente: Aoboshi_One (c:/tmp/content/ocr_fonts_latin\Aoboshi_One\Aoboshi_One-regular.ttf)
# Generando caracteres para la fuente: Arbutus (c:/tmp/content/ocr_fonts_latin\Arbutus\Arbutus-regular.ttf)
# Generando caracteres para la fuente: Arbutus_Slab (c:/tmp/content/ocr_fonts_latin\Arbutus_Slab\Arbutus_Slab-regular.ttf)
# Generando caracteres para la fuente: Architects_Daughter (c:/tmp/content/ocr_fonts_latin\Architects_Daughter\Architects_Daughter-regular.ttf)
# Generando caracteres para la fuente: Archivo (c:/tmp/content/ocr_fonts_latin\Archivo\Archivo-100.ttf)
# Generando caracteres para la fuente: Archivo_Black (c:/tmp/content/ocr_fonts_latin\Archivo_Black\Archivo_Black-regular.ttf)
# Generando caracteres para la fuente: Archivo_Narrow (c:/tmp/content/ocr_fonts_latin\Archivo_Narrow\Archivo_Narrow-500.ttf)
# Generando caracteres para la fuente: Aref_Ruqaa (c:/tmp/content/ocr_fonts_latin\Aref_Ruqaa\Aref_Ruqaa-700.ttf)
# Generando caracteres para la fuente: Aref_Ruqaa_Ink (c:/tmp/content/ocr_fonts_latin\Aref_Ruqaa_Ink\Aref_Ruqaa_Ink-700.ttf)
# Generando caracteres para la fuente: Are_You_Serious (c:/tmp/content/ocr_fonts_latin\Are_You_Serious\Are_You_Serious-regular.ttf)
# Generando caracteres para la fuente: Arima (c:/tmp/content/ocr_fonts_latin\Arima\Arima-100.ttf)
# Generando caracteres para la fuente: Arimo (c:/tmp/content/ocr_fonts_latin\Arimo\Arimo-500.ttf)
# Generando caracteres para la fuente: Arizonia (c:/tmp/content/ocr_fonts_latin\Arizonia\Arizonia-regular.ttf)
# Generando caracteres para la fuente: Armata (c:/tmp/content/ocr_fonts_latin\Armata\Armata-regular.ttf)
# Generando caracteres para la fuente: Arsenal (c:/tmp/content/ocr_fonts_latin\Arsenal\Arsenal-700.ttf)
# Generando caracteres para la fuente: Arsenal_SC (c:/tmp/content/ocr_fonts_latin\Arsenal_SC\Arsenal_SC-700.ttf)
# Generando caracteres para la fuente: Arya (c:/tmp/content/ocr_fonts_latin\Arya\Arya-700.ttf)
# Generando caracteres para la fuente: AR_One_Sans (c:/tmp/content/ocr_fonts_latin\AR_One_Sans\AR_One_Sans-500.ttf)
# Generando caracteres para la fuente: Asap (c:/tmp/content/ocr_fonts_latin\Asap\Asap-100.ttf)
# Generando caracteres para la fuente: Asap_Condensed (c:/tmp/content/ocr_fonts_latin\Asap_Condensed\Asap_Condensed-200.ttf)
# Generando caracteres para la fuente: Asar (c:/tmp/content/ocr_fonts_latin\Asar\Asar-regular.ttf)
# Generando caracteres para la fuente: Asset (c:/tmp/content/ocr_fonts_latin\Asset\Asset-regular.ttf)
# Generando caracteres para la fuente: Assistant (c:/tmp/content/ocr_fonts_latin\Assistant\Assistant-200.ttf)
# Generando caracteres para la fuente: Athiti (c:/tmp/content/ocr_fonts_latin\Athiti\Athiti-200.ttf)
# Generando caracteres para la fuente: Atkinson_Hyperlegible (c:/tmp/content/ocr_fonts_latin\Atkinson_Hyperlegible\Atkinson_Hyperlegible-700.ttf)
# Generando caracteres para la fuente: Atkinson_Hyperlegible_Mono (c:/tmp/content/ocr_fonts_latin\Atkinson_Hyperlegible_Mono\Atkinson_Hyperlegible_Mono-200.ttf)
# Generando caracteres para la fuente: Atkinson_Hyperlegible_Next (c:/tmp/content/ocr_fonts_latin\Atkinson_Hyperlegible_Next\Atkinson_Hyperlegible_Next-200.ttf)
# Generando caracteres para la fuente: Atma (c:/tmp/content/ocr_fonts_latin\Atma\Atma-300.ttf)
# Generando caracteres para la fuente: Atomic_Age (c:/tmp/content/ocr_fonts_latin\Atomic_Age\Atomic_Age-regular.ttf)
# Generando caracteres para la fuente: Audiowide (c:/tmp/content/ocr_fonts_latin\Audiowide\Audiowide-Regular.ttf)
# Generando caracteres para la fuente: Autour_One (c:/tmp/content/ocr_fonts_latin\Autour_One\Autour_One-regular.ttf)
# Generando caracteres para la fuente: Average (c:/tmp/content/ocr_fonts_latin\Average\Average-regular.ttf)
# Generando caracteres para la fuente: Average_Sans (c:/tmp/content/ocr_fonts_latin\Average_Sans\Average_Sans-regular.ttf)
# Generando caracteres para la fuente: Averia_Gruesa_Libre (c:/tmp/content/ocr_fonts_latin\Averia_Gruesa_Libre\Averia_Gruesa_Libre-regular.ttf)
# Generando caracteres para la fuente: Azeret_Mono (c:/tmp/content/ocr_fonts_latin\Azeret_Mono\Azeret_Mono-100.ttf)
# Generando caracteres para la fuente: Babylonica (c:/tmp/content/ocr_fonts_latin\Babylonica\Babylonica-regular.ttf)
# Generando caracteres para la fuente: Bacasime_Antique (c:/tmp/content/ocr_fonts_latin\Bacasime_Antique\Bacasime_Antique-regular.ttf)
# Generando caracteres para la fuente: Badeen_Display (c:/tmp/content/ocr_fonts_latin\Badeen_Display\Badeen_Display-regular.ttf)
# Generando caracteres para la fuente: Bad_Script (c:/tmp/content/ocr_fonts_latin\Bad_Script\Bad_Script-regular.ttf)
# Generando caracteres para la fuente: Bagel_Fat_One (c:/tmp/content/ocr_fonts_latin\Bagel_Fat_One\Bagel_Fat_One-regular.ttf)
# Generando caracteres para la fuente: Bahiana (c:/tmp/content/ocr_fonts_latin\Bahiana\Bahiana-regular.ttf)
# Generando caracteres para la fuente: Bahianita (c:/tmp/content/ocr_fonts_latin\Bahianita\Bahianita-regular.ttf)
# Generando caracteres para la fuente: Bai_Jamjuree (c:/tmp/content/ocr_fonts_latin\Bai_Jamjuree\Bai_Jamjuree-200.ttf)
# Generando caracteres para la fuente: Bakbak_One (c:/tmp/content/ocr_fonts_latin\Bakbak_One\Bakbak_One-regular.ttf)
# Generando caracteres para la fuente: Ballet (c:/tmp/content/ocr_fonts_latin\Ballet\Ballet-regular.ttf)
# Generando caracteres para la fuente: Baloo_2 (c:/tmp/content/ocr_fonts_latin\Baloo_2\Baloo_2-500.ttf)
# Generando caracteres para la fuente: Baloo_Bhaijaan_2 (c:/tmp/content/ocr_fonts_latin\Baloo_Bhaijaan_2\Baloo_Bhaijaan_2-500.ttf)
# Generando caracteres para la fuente: Baloo_Bhaina_2 (c:/tmp/content/ocr_fonts_latin\Baloo_Bhaina_2\Baloo_Bhaina_2-500.ttf)
# Generando caracteres para la fuente: Baloo_Bhai_2 (c:/tmp/content/ocr_fonts_latin\Baloo_Bhai_2\Baloo_Bhai_2-500.ttf)
# Generando caracteres para la fuente: Baloo_Chettan_2 (c:/tmp/content/ocr_fonts_latin\Baloo_Chettan_2\Baloo_Chettan_2-500.ttf)
# Generando caracteres para la fuente: Baloo_Da_2 (c:/tmp/content/ocr_fonts_latin\Baloo_Da_2\Baloo_Da_2-500.ttf)
# Generando caracteres para la fuente: Baloo_Paaji_2 (c:/tmp/content/ocr_fonts_latin\Baloo_Paaji_2\Baloo_Paaji_2-500.ttf)
# Generando caracteres para la fuente: Baloo_Tamma_2 (c:/tmp/content/ocr_fonts_latin\Baloo_Tamma_2\Baloo_Tamma_2-500.ttf)
# Generando caracteres para la fuente: Baloo_Tammudu_2 (c:/tmp/content/ocr_fonts_latin\Baloo_Tammudu_2\Baloo_Tammudu_2-500.ttf)
# Generando caracteres para la fuente: Baloo_Thambi_2 (c:/tmp/content/ocr_fonts_latin\Baloo_Thambi_2\Baloo_Thambi_2-500.ttf)
# Generando caracteres para la fuente: Balsamiq_Sans (c:/tmp/content/ocr_fonts_latin\Balsamiq_Sans\Balsamiq_Sans-700.ttf)
# Generando caracteres para la fuente: Bangers (c:/tmp/content/ocr_fonts_latin\Bangers\Bangers-regular.ttf)
# Generando caracteres para la fuente: Barlow (c:/tmp/content/ocr_fonts_latin\Barlow\Barlow-100.ttf)
# Generando caracteres para la fuente: Barlow_Condensed (c:/tmp/content/ocr_fonts_latin\Barlow_Condensed\Barlow_Condensed-100.ttf)
# Generando caracteres para la fuente: Barlow_Semi_Condensed (c:/tmp/content/ocr_fonts_latin\Barlow_Semi_Condensed\Barlow_Semi_Condensed-100.ttf)
# Generando caracteres para la fuente: Barriecito (c:/tmp/content/ocr_fonts_latin\Barriecito\Barriecito-regular.ttf)
# Generando caracteres para la fuente: Barrio (c:/tmp/content/ocr_fonts_latin\Barrio\Barrio-regular.ttf)
# Generando caracteres para la fuente: Basic (c:/tmp/content/ocr_fonts_latin\Basic\Basic-regular.ttf)
# Generando caracteres para la fuente: Baskervville (c:/tmp/content/ocr_fonts_latin\Baskervville\Baskervville-500.ttf)
# Generando caracteres para la fuente: Baskervville_SC (c:/tmp/content/ocr_fonts_latin\Baskervville_SC\Baskervville_SC-500.ttf)
# Generando caracteres para la fuente: Beau_Rivage (c:/tmp/content/ocr_fonts_latin\Beau_Rivage\Beau_Rivage-regular.ttf)
# Generando caracteres para la fuente: Bebas_Neue (c:/tmp/content/ocr_fonts_latin\Bebas_Neue\Bebas_Neue-regular.ttf)
# Generando caracteres para la fuente: Beiruti (c:/tmp/content/ocr_fonts_latin\Beiruti\Beiruti-200.ttf)
# Generando caracteres para la fuente: Belanosima (c:/tmp/content/ocr_fonts_latin\Belanosima\Belanosima-600.ttf)
# Generando caracteres para la fuente: Bellefair (c:/tmp/content/ocr_fonts_latin\Bellefair\Bellefair-regular.ttf)
# Generando caracteres para la fuente: Belleza (c:/tmp/content/ocr_fonts_latin\Belleza\Belleza-regular.ttf)
# Generando caracteres para la fuente: Bellota (c:/tmp/content/ocr_fonts_latin\Bellota\Bellota-300.ttf)
# Generando caracteres para la fuente: Bellota_Text (c:/tmp/content/ocr_fonts_latin\Bellota_Text\Bellota_Text-300.ttf)
# Generando caracteres para la fuente: BenchNine (c:/tmp/content/ocr_fonts_latin\BenchNine\BenchNine-300.ttf)
# Generando caracteres para la fuente: Benne (c:/tmp/content/ocr_fonts_latin\Benne\Benne-regular.ttf)
# Generando caracteres para la fuente: Bentham (c:/tmp/content/ocr_fonts_latin\Bentham\Bentham-regular.ttf)
# Generando caracteres para la fuente: Berkshire_Swash (c:/tmp/content/ocr_fonts_latin\Berkshire_Swash\Berkshire_Swash-regular.ttf)
# Generando caracteres para la fuente: Besley (c:/tmp/content/ocr_fonts_latin\Besley\Besley-500.ttf)
# Generando caracteres para la fuente: Bevan (c:/tmp/content/ocr_fonts_latin\Bevan\Bevan-italic.ttf)
# Generando caracteres para la fuente: Be_Vietnam_Pro (c:/tmp/content/ocr_fonts_latin\Be_Vietnam_Pro\Be_Vietnam_Pro-100.ttf)
# Generando caracteres para la fuente: BhuTuka_Expanded_One (c:/tmp/content/ocr_fonts_latin\BhuTuka_Expanded_One\BhuTuka_Expanded_One-regular.ttf)
# Generando caracteres para la fuente: Bigelow_Rules (c:/tmp/content/ocr_fonts_latin\Bigelow_Rules\Bigelow_Rules-regular.ttf)
# Generando caracteres para la fuente: Big_Shoulders (c:/tmp/content/ocr_fonts_latin\Big_Shoulders\Big_Shoulders-100.ttf)
# Generando caracteres para la fuente: Big_Shoulders_Inline (c:/tmp/content/ocr_fonts_latin\Big_Shoulders_Inline\Big_Shoulders_Inline-100.ttf)
# Generando caracteres para la fuente: Big_Shoulders_Stencil (c:/tmp/content/ocr_fonts_latin\Big_Shoulders_Stencil\Big_Shoulders_Stencil-100.ttf)
# Generando caracteres para la fuente: Bilbo (c:/tmp/content/ocr_fonts_latin\Bilbo\Bilbo-regular.ttf)
# Generando caracteres para la fuente: Bilbo_Swash_Caps (c:/tmp/content/ocr_fonts_latin\Bilbo_Swash_Caps\Bilbo_Swash_Caps-regular.ttf)
# Generando caracteres para la fuente: BioRhyme (c:/tmp/content/ocr_fonts_latin\BioRhyme\BioRhyme-200.ttf)
# Generando caracteres para la fuente: BioRhyme_Expanded (c:/tmp/content/ocr_fonts_latin\BioRhyme_Expanded\BioRhyme_Expanded-200.ttf)
# Generando caracteres para la fuente: Birthstone (c:/tmp/content/ocr_fonts_latin\Birthstone\Birthstone-regular.ttf)
# Generando caracteres para la fuente: Birthstone_Bounce (c:/tmp/content/ocr_fonts_latin\Birthstone_Bounce\Birthstone_Bounce-500.ttf)
# Generando caracteres para la fuente: Biryani (c:/tmp/content/ocr_fonts_latin\Biryani\Biryani-200.ttf)
# Generando caracteres para la fuente: Bitter (c:/tmp/content/ocr_fonts_latin\Bitter\Bitter-100.ttf)
# Generando caracteres para la fuente: BIZ_UDGothic (c:/tmp/content/ocr_fonts_latin\BIZ_UDGothic\BIZ_UDGothic-700.ttf)
# Generando caracteres para la fuente: BIZ_UDMincho (c:/tmp/content/ocr_fonts_latin\BIZ_UDMincho\BIZ_UDMincho-700.ttf)
# Generando caracteres para la fuente: BIZ_UDPGothic (c:/tmp/content/ocr_fonts_latin\BIZ_UDPGothic\BIZ_UDPGothic-700.ttf)
# Generando caracteres para la fuente: BIZ_UDPMincho (c:/tmp/content/ocr_fonts_latin\BIZ_UDPMincho\BIZ_UDPMincho-700.ttf)
# Generando caracteres para la fuente: Black_Ops_One (c:/tmp/content/ocr_fonts_latin\Black_Ops_One\Black_Ops_One-regular.ttf)
# Generando caracteres para la fuente: Blaka (c:/tmp/content/ocr_fonts_latin\Blaka\Blaka-regular.ttf)
# Generando caracteres para la fuente: Blaka_Hollow (c:/tmp/content/ocr_fonts_latin\Blaka_Hollow\Blaka_Hollow-regular.ttf)
# Generando caracteres para la fuente: Blaka_Ink (c:/tmp/content/ocr_fonts_latin\Blaka_Ink\Blaka_Ink-regular.ttf)
# Generando caracteres para la fuente: Blinker (c:/tmp/content/ocr_fonts_latin\Blinker\Blinker-100.ttf)
# Generando caracteres para la fuente: Bodoni_Moda (c:/tmp/content/ocr_fonts_latin\Bodoni_Moda\Bodoni_Moda-500.ttf)
# Generando caracteres para la fuente: Bodoni_Moda_SC (c:/tmp/content/ocr_fonts_latin\Bodoni_Moda_SC\Bodoni_Moda_SC-500.ttf)
# Generando caracteres para la fuente: Boldonse (c:/tmp/content/ocr_fonts_latin\Boldonse\Boldonse-regular.ttf)
# Generando caracteres para la fuente: Bona_Nova (c:/tmp/content/ocr_fonts_latin\Bona_Nova\Bona_Nova-700.ttf)
# Generando caracteres para la fuente: Bona_Nova_SC (c:/tmp/content/ocr_fonts_latin\Bona_Nova_SC\Bona_Nova_SC-700.ttf)
# Generando caracteres para la fuente: Bonheur_Royale (c:/tmp/content/ocr_fonts_latin\Bonheur_Royale\Bonheur_Royale-regular.ttf)
# Generando caracteres para la fuente: Borel (c:/tmp/content/ocr_fonts_latin\Borel\Borel-regular.ttf)
# Generando caracteres para la fuente: Bowlby_One_SC (c:/tmp/content/ocr_fonts_latin\Bowlby_One_SC\BowlbyOneSC-Regular.ttf)
# Generando caracteres para la fuente: Braah_One (c:/tmp/content/ocr_fonts_latin\Braah_One\Braah_One-regular.ttf)
# Generando caracteres para la fuente: Bree_Serif (c:/tmp/content/ocr_fonts_latin\Bree_Serif\Bree_Serif-regular.ttf)
# Generando caracteres para la fuente: Bricolage_Grotesque (c:/tmp/content/ocr_fonts_latin\Bricolage_Grotesque\Bricolage_Grotesque-200.ttf)
# Generando caracteres para la fuente: Bruno_Ace (c:/tmp/content/ocr_fonts_latin\Bruno_Ace\Bruno_Ace-regular.ttf)
# Generando caracteres para la fuente: Bruno_Ace_SC (c:/tmp/content/ocr_fonts_latin\Bruno_Ace_SC\Bruno_Ace_SC-regular.ttf)
# Generando caracteres para la fuente: Brygada_1918 (c:/tmp/content/ocr_fonts_latin\Brygada_1918\Brygada_1918-500.ttf)
# Generando caracteres para la fuente: Bubblegum_Sans (c:/tmp/content/ocr_fonts_latin\Bubblegum_Sans\Bubblegum_Sans-regular.ttf)
# Generando caracteres para la fuente: Bubbler_One (c:/tmp/content/ocr_fonts_latin\Bubbler_One\Bubbler_One-regular.ttf)
# Generando caracteres para la fuente: Buenard (c:/tmp/content/ocr_fonts_latin\Buenard\Buenard-500.ttf)
# Generando caracteres para la fuente: Bungee (c:/tmp/content/ocr_fonts_latin\Bungee\Bungee-regular.ttf)
# Generando caracteres para la fuente: Bungee_Hairline (c:/tmp/content/ocr_fonts_latin\Bungee_Hairline\Bungee_Hairline-regular.ttf)
# Generando caracteres para la fuente: Bungee_Inline (c:/tmp/content/ocr_fonts_latin\Bungee_Inline\Bungee_Inline-regular.ttf)
# Generando caracteres para la fuente: Bungee_Outline (c:/tmp/content/ocr_fonts_latin\Bungee_Outline\Bungee_Outline-regular.ttf)
# Generando caracteres para la fuente: Bungee_Shade (c:/tmp/content/ocr_fonts_latin\Bungee_Shade\Bungee_Shade-regular.ttf)
# Generando caracteres para la fuente: Bungee_Spice (c:/tmp/content/ocr_fonts_latin\Bungee_Spice\Bungee_Spice-regular.ttf)
# Generando caracteres para la fuente: Bungee_Tint (c:/tmp/content/ocr_fonts_latin\Bungee_Tint\Bungee_Tint-regular.ttf)
# Generando caracteres para la fuente: Butcherman (c:/tmp/content/ocr_fonts_latin\Butcherman\Butcherman-regular.ttf)
# Generando caracteres para la fuente: Butterfly_Kids (c:/tmp/content/ocr_fonts_latin\Butterfly_Kids\Butterfly_Kids-regular.ttf)
# Generando caracteres para la fuente: Bytesized (c:/tmp/content/ocr_fonts_latin\Bytesized\Bytesized-regular.ttf)
# Generando caracteres para la fuente: Cabin (c:/tmp/content/ocr_fonts_latin\Cabin\Cabin-500.ttf)
# Generando caracteres para la fuente: Cabin_Condensed (c:/tmp/content/ocr_fonts_latin\Cabin_Condensed\Cabin_Condensed-500.ttf)
# Generando caracteres para la fuente: Cactus_Classical_Serif (c:/tmp/content/ocr_fonts_latin\Cactus_Classical_Serif\Cactus_Classical_Serif-regular.ttf)
# Generando caracteres para la fuente: Cairo (c:/tmp/content/ocr_fonts_latin\Cairo\Cairo-200.ttf)
# Generando caracteres para la fuente: Cairo_Play (c:/tmp/content/ocr_fonts_latin\Cairo_Play\Cairo_Play-200.ttf)
# Generando caracteres para la fuente: Caladea (c:/tmp/content/ocr_fonts_latin\Caladea\Caladea-700.ttf)
# Generando caracteres para la fuente: Calistoga (c:/tmp/content/ocr_fonts_latin\Calistoga\Calistoga-regular.ttf)
# Generando caracteres para la fuente: Cal_Sans (c:/tmp/content/ocr_fonts_latin\Cal_Sans\Cal_Sans-regular.ttf)
# Generando caracteres para la fuente: Cambay (c:/tmp/content/ocr_fonts_latin\Cambay\Cambay-700.ttf)
# Generando caracteres para la fuente: Cambo (c:/tmp/content/ocr_fonts_latin\Cambo\Cambo-regular.ttf)
# Generando caracteres para la fuente: Cantarell (c:/tmp/content/ocr_fonts_latin\Cantarell\Cantarell-700.ttf)
# Generando caracteres para la fuente: Cantata_One (c:/tmp/content/ocr_fonts_latin\Cantata_One\Cantata_One-regular.ttf)
# Generando caracteres para la fuente: Cantora_One (c:/tmp/content/ocr_fonts_latin\Cantora_One\Cantora_One-regular.ttf)
# Generando caracteres para la fuente: Caprasimo (c:/tmp/content/ocr_fonts_latin\Caprasimo\Caprasimo-regular.ttf)
# Generando caracteres para la fuente: Capriola (c:/tmp/content/ocr_fonts_latin\Capriola\Capriola-regular.ttf)
# Generando caracteres para la fuente: Caramel (c:/tmp/content/ocr_fonts_latin\Caramel\Caramel-regular.ttf)
# Generando caracteres para la fuente: Carattere (c:/tmp/content/ocr_fonts_latin\Carattere\Carattere-regular.ttf)
# Generando caracteres para la fuente: Cardo (c:/tmp/content/ocr_fonts_latin\Cardo\Cardo-700.ttf)
# Generando caracteres para la fuente: Carlito (c:/tmp/content/ocr_fonts_latin\Carlito\Carlito-700.ttf)
# Generando caracteres para la fuente: Cascadia_Code (c:/tmp/content/ocr_fonts_latin\Cascadia_Code\Cascadia_Code-200.ttf)
# Generando caracteres para la fuente: Cascadia_Mono (c:/tmp/content/ocr_fonts_latin\Cascadia_Mono\Cascadia_Mono-200.ttf)
# Generando caracteres para la fuente: Castoro (c:/tmp/content/ocr_fonts_latin\Castoro\Castoro-italic.ttf)
# Generando caracteres para la fuente: Castoro_Titling (c:/tmp/content/ocr_fonts_latin\Castoro_Titling\Castoro_Titling-regular.ttf)
# Generando caracteres para la fuente: Catamaran (c:/tmp/content/ocr_fonts_latin\Catamaran\Catamaran-100.ttf)
# Generando caracteres para la fuente: Caudex (c:/tmp/content/ocr_fonts_latin\Caudex\Caudex-700.ttf)
# Generando caracteres para la fuente: Caveat (c:/tmp/content/ocr_fonts_latin\Caveat\Caveat-500.ttf)
# Generando caracteres para la fuente: Caveat_Brush (c:/tmp/content/ocr_fonts_latin\Caveat_Brush\Caveat_Brush-regular.ttf)
# Generando caracteres para la fuente: Ceviche_One (c:/tmp/content/ocr_fonts_latin\Ceviche_One\Ceviche_One-regular.ttf)
# Generando caracteres para la fuente: Chakra_Petch (c:/tmp/content/ocr_fonts_latin\Chakra_Petch\Chakra_Petch-300.ttf)
# Generando caracteres para la fuente: Changa (c:/tmp/content/ocr_fonts_latin\Changa\Changa-200.ttf)
# Generando caracteres para la fuente: Chango (c:/tmp/content/ocr_fonts_latin\Chango\Chango-regular.ttf)
# Generando caracteres para la fuente: Charis_SIL (c:/tmp/content/ocr_fonts_latin\Charis_SIL\Charis_SIL-700.ttf)
# Generando caracteres para la fuente: Charm (c:/tmp/content/ocr_fonts_latin\Charm\Charm-700.ttf)
# Generando caracteres para la fuente: Charmonman (c:/tmp/content/ocr_fonts_latin\Charmonman\Charmonman-700.ttf)
# Generando caracteres para la fuente: Chau_Philomene_One (c:/tmp/content/ocr_fonts_latin\Chau_Philomene_One\Chau_Philomene_One-italic.ttf)
# Generando caracteres para la fuente: Chela_One (c:/tmp/content/ocr_fonts_latin\Chela_One\Chela_One-regular.ttf)
# Generando caracteres para la fuente: Chelsea_Market (c:/tmp/content/ocr_fonts_latin\Chelsea_Market\Chelsea_Market-regular.ttf)
# Generando caracteres para la fuente: Cherish (c:/tmp/content/ocr_fonts_latin\Cherish\Cherish-regular.ttf)
# Generando caracteres para la fuente: Cherry_Bomb_One (c:/tmp/content/ocr_fonts_latin\Cherry_Bomb_One\Cherry_Bomb_One-regular.ttf)
# Generando caracteres para la fuente: Cherry_Swash (c:/tmp/content/ocr_fonts_latin\Cherry_Swash\Cherry_Swash-700.ttf)
# Generando caracteres para la fuente: Chicle (c:/tmp/content/ocr_fonts_latin\Chicle\Chicle-regular.ttf)
# Generando caracteres para la fuente: Chilanka (c:/tmp/content/ocr_fonts_latin\Chilanka\Chilanka-regular.ttf)
# Generando caracteres para la fuente: Chivo (c:/tmp/content/ocr_fonts_latin\Chivo\Chivo-100.ttf)
# Generando caracteres para la fuente: Chivo_Mono (c:/tmp/content/ocr_fonts_latin\Chivo_Mono\Chivo_Mono-100.ttf)
# Generando caracteres para la fuente: Chocolate_Classical_Sans (c:/tmp/content/ocr_fonts_latin\Chocolate_Classical_Sans\Chocolate_Classical_Sans-regular.ttf)
# Generando caracteres para la fuente: Chokokutai (c:/tmp/content/ocr_fonts_latin\Chokokutai\Chokokutai-regular.ttf)
# Generando caracteres para la fuente: Chonburi (c:/tmp/content/ocr_fonts_latin\Chonburi\Chonburi-regular.ttf)
# Generando caracteres para la fuente: Cinzel (c:/tmp/content/ocr_fonts_latin\Cinzel\Cinzel-500.ttf)
# Generando caracteres para la fuente: Cinzel_Decorative (c:/tmp/content/ocr_fonts_latin\Cinzel_Decorative\Cinzel_Decorative-700.ttf)
# Generando caracteres para la fuente: Clicker_Script (c:/tmp/content/ocr_fonts_latin\Clicker_Script\Clicker_Script-regular.ttf)
# Generando caracteres para la fuente: Climate_Crisis (c:/tmp/content/ocr_fonts_latin\Climate_Crisis\Climate_Crisis-regular.ttf)
# Generando caracteres para la fuente: Coda (c:/tmp/content/ocr_fonts_latin\Coda\Coda-800.ttf)
# Generando caracteres para la fuente: Codystar (c:/tmp/content/ocr_fonts_latin\Codystar\Codystar-300.ttf)
# Generando caracteres para la fuente: Coiny (c:/tmp/content/ocr_fonts_latin\Coiny\Coiny-regular.ttf)
# Generando caracteres para la fuente: Combo (c:/tmp/content/ocr_fonts_latin\Combo\Combo-regular.ttf)
# Generando caracteres para la fuente: Comfortaa (c:/tmp/content/ocr_fonts_latin\Comfortaa\Comfortaa-300.ttf)
# Generando caracteres para la fuente: Comforter (c:/tmp/content/ocr_fonts_latin\Comforter\Comforter-regular.ttf)
# Generando caracteres para la fuente: Comforter_Brush (c:/tmp/content/ocr_fonts_latin\Comforter_Brush\Comforter_Brush-regular.ttf)
# Generando caracteres para la fuente: Comic_Relief (c:/tmp/content/ocr_fonts_latin\Comic_Relief\Comic_Relief-700.ttf)
# Generando caracteres para la fuente: Comme (c:/tmp/content/ocr_fonts_latin\Comme\Comme-100.ttf)
# Generando caracteres para la fuente: Commissioner (c:/tmp/content/ocr_fonts_latin\Commissioner\Commissioner-100.ttf)
# Generando caracteres para la fuente: Concert_One (c:/tmp/content/ocr_fonts_latin\Concert_One\Concert_One-regular.ttf)
# Generando caracteres para la fuente: Condiment (c:/tmp/content/ocr_fonts_latin\Condiment\Condiment-regular.ttf)
# Generando caracteres para la fuente: Convergence (c:/tmp/content/ocr_fonts_latin\Convergence\Convergence-regular.ttf)
# Generando caracteres para la fuente: Cookie (c:/tmp/content/ocr_fonts_latin\Cookie\Cookie-Regular.ttf)
# Generando caracteres para la fuente: Coral_Pixels (c:/tmp/content/ocr_fonts_latin\Coral_Pixels\Coral_Pixels-regular.ttf)
# Generando caracteres para la fuente: Corben (c:/tmp/content/ocr_fonts_latin\Corben\Corben-700.ttf)
# Generando caracteres para la fuente: Corinthia (c:/tmp/content/ocr_fonts_latin\Corinthia\Corinthia-700.ttf)
# Generando caracteres para la fuente: Cormorant (c:/tmp/content/ocr_fonts_latin\Cormorant\Cormorant-300.ttf)
# Generando caracteres para la fuente: Cormorant_Garamond (c:/tmp/content/ocr_fonts_latin\Cormorant_Garamond\Cormorant_Garamond-300.ttf)
# Generando caracteres para la fuente: Cormorant_Infant (c:/tmp/content/ocr_fonts_latin\Cormorant_Infant\Cormorant_Infant-300.ttf)
# Generando caracteres para la fuente: Cormorant_SC (c:/tmp/content/ocr_fonts_latin\Cormorant_SC\Cormorant_SC-300.ttf)
# Generando caracteres para la fuente: Cormorant_Unicase (c:/tmp/content/ocr_fonts_latin\Cormorant_Unicase\Cormorant_Unicase-300.ttf)
# Generando caracteres para la fuente: Cormorant_Upright (c:/tmp/content/ocr_fonts_latin\Cormorant_Upright\Cormorant_Upright-300.ttf)
# Generando caracteres para la fuente: Courgette (c:/tmp/content/ocr_fonts_latin\Courgette\Courgette-regular.ttf)
# Generando caracteres para la fuente: Courier_Prime (c:/tmp/content/ocr_fonts_latin\Courier_Prime\Courier_Prime-700.ttf)
# Generando caracteres para la fuente: Cousine (c:/tmp/content/ocr_fonts_latin\Cousine\Cousine-700.ttf)
# Generando caracteres para la fuente: Covered_By_Your_Grace (c:/tmp/content/ocr_fonts_latin\Covered_By_Your_Grace\Covered_By_Your_Grace-regular.ttf)
# Generando caracteres para la fuente: Crete_Round (c:/tmp/content/ocr_fonts_latin\Crete_Round\Crete_Round-italic.ttf)
# Generando caracteres para la fuente: Crimson_Pro (c:/tmp/content/ocr_fonts_latin\Crimson_Pro\Crimson_Pro-200.ttf)
# Generando caracteres para la fuente: Crimson_Text (c:/tmp/content/ocr_fonts_latin\Crimson_Text\Crimson_Text-600.ttf)
# Generando caracteres para la fuente: Croissant_One (c:/tmp/content/ocr_fonts_latin\Croissant_One\Croissant_One-regular.ttf)
# Generando caracteres para la fuente: Crushed (c:/tmp/content/ocr_fonts_latin\Crushed\Crushed-regular.ttf)
# Generando caracteres para la fuente: Cuprum (c:/tmp/content/ocr_fonts_latin\Cuprum\Cuprum-500.ttf)
# Generando caracteres para la fuente: Cutive (c:/tmp/content/ocr_fonts_latin\Cutive\Cutive-regular.ttf)
# Generando caracteres para la fuente: Cutive_Mono (c:/tmp/content/ocr_fonts_latin\Cutive_Mono\Cutive_Mono-regular.ttf)
# Generando caracteres para la fuente: Dai_Banna_SIL (c:/tmp/content/ocr_fonts_latin\Dai_Banna_SIL\Dai_Banna_SIL-300.ttf)
# Generando caracteres para la fuente: Damion (c:/tmp/content/ocr_fonts_latin\Damion\Damion-regular.ttf)
# Generando caracteres para la fuente: Dancing_Script (c:/tmp/content/ocr_fonts_latin\Dancing_Script\Dancing_Script-500.ttf)
# Generando caracteres para la fuente: Danfo (c:/tmp/content/ocr_fonts_latin\Danfo\Danfo-regular.ttf)
# Generando caracteres para la fuente: Darker_Grotesque (c:/tmp/content/ocr_fonts_latin\Darker_Grotesque\Darker_Grotesque-300.ttf)
# Generando caracteres para la fuente: Darumadrop_One (c:/tmp/content/ocr_fonts_latin\Darumadrop_One\Darumadrop_One-regular.ttf)
# Generando caracteres para la fuente: David_Libre (c:/tmp/content/ocr_fonts_latin\David_Libre\David_Libre-500.ttf)
# Generando caracteres para la fuente: Dekko (c:/tmp/content/ocr_fonts_latin\Dekko\Dekko-regular.ttf)
# Generando caracteres para la fuente: Dela_Gothic_One (c:/tmp/content/ocr_fonts_latin\Dela_Gothic_One\Dela_Gothic_One-regular.ttf)
# Generando caracteres para la fuente: Delicious_Handrawn (c:/tmp/content/ocr_fonts_latin\Delicious_Handrawn\Delicious_Handrawn-regular.ttf)
# Generando caracteres para la fuente: Denk_One (c:/tmp/content/ocr_fonts_latin\Denk_One\Denk_One-regular.ttf)
# Generando caracteres para la fuente: Devonshire (c:/tmp/content/ocr_fonts_latin\Devonshire\Devonshire-regular.ttf)
# Generando caracteres para la fuente: Didact_Gothic (c:/tmp/content/ocr_fonts_latin\Didact_Gothic\Didact_Gothic-regular.ttf)
# Generando caracteres para la fuente: Diphylleia (c:/tmp/content/ocr_fonts_latin\Diphylleia\Diphylleia-regular.ttf)
# Generando caracteres para la fuente: Diplomata (c:/tmp/content/ocr_fonts_latin\Diplomata\Diplomata-regular.ttf)
# Generando caracteres para la fuente: Diplomata_SC (c:/tmp/content/ocr_fonts_latin\Diplomata_SC\Diplomata_SC-regular.ttf)
# Generando caracteres para la fuente: DM_Mono (c:/tmp/content/ocr_fonts_latin\DM_Mono\DM_Mono-300.ttf)
# Generando caracteres para la fuente: DM_Sans (c:/tmp/content/ocr_fonts_latin\DM_Sans\DM_Sans-100.ttf)
# Generando caracteres para la fuente: DM_Serif_Display (c:/tmp/content/ocr_fonts_latin\DM_Serif_Display\DM_Serif_Display-italic.ttf)
# Generando caracteres para la fuente: DM_Serif_Text (c:/tmp/content/ocr_fonts_latin\DM_Serif_Text\DM_Serif_Text-italic.ttf)
# Generando caracteres para la fuente: Domine (c:/tmp/content/ocr_fonts_latin\Domine\Domine-500.ttf)
# Generando caracteres para la fuente: Donegal_One (c:/tmp/content/ocr_fonts_latin\Donegal_One\Donegal_One-regular.ttf)
# Generando caracteres para la fuente: Dongle (c:/tmp/content/ocr_fonts_latin\Dongle\Dongle-300.ttf)
# Generando caracteres para la fuente: Doppio_One (c:/tmp/content/ocr_fonts_latin\Doppio_One\Doppio_One-regular.ttf)
# Generando caracteres para la fuente: Dosis (c:/tmp/content/ocr_fonts_latin\Dosis\Dosis-200.ttf)
# Generando caracteres para la fuente: DotGothic16 (c:/tmp/content/ocr_fonts_latin\DotGothic16\DotGothic16-regular.ttf)
# Generando caracteres para la fuente: Doto (c:/tmp/content/ocr_fonts_latin\Doto\Doto-100.ttf)
# Generando caracteres para la fuente: Dr_Sugiyama (c:/tmp/content/ocr_fonts_latin\Dr_Sugiyama\Dr_Sugiyama-regular.ttf)
# Generando caracteres para la fuente: Duru_Sans (c:/tmp/content/ocr_fonts_latin\Duru_Sans\Duru_Sans-regular.ttf)
# Generando caracteres para la fuente: Dynalight (c:/tmp/content/ocr_fonts_latin\Dynalight\Dynalight-regular.ttf)
# Generando caracteres para la fuente: DynaPuff (c:/tmp/content/ocr_fonts_latin\DynaPuff\DynaPuff-500.ttf)
# Generando caracteres para la fuente: Eagle_Lake (c:/tmp/content/ocr_fonts_latin\Eagle_Lake\Eagle_Lake-regular.ttf)
# Generando caracteres para la fuente: Eater (c:/tmp/content/ocr_fonts_latin\Eater\Eater-regular.ttf)
# Generando caracteres para la fuente: EB_Garamond (c:/tmp/content/ocr_fonts_latin\EB_Garamond\EB_Garamond-500.ttf)
# Generando caracteres para la fuente: Economica (c:/tmp/content/ocr_fonts_latin\Economica\Economica-700.ttf)
# Generando caracteres para la fuente: Eczar (c:/tmp/content/ocr_fonts_latin\Eczar\Eczar-500.ttf)
# Generando caracteres para la fuente: Edu_AU_VIC_WA_NT_Arrows (c:/tmp/content/ocr_fonts_latin\Edu_AU_VIC_WA_NT_Arrows\Edu_AU_VIC_WA_NT_Arrows-500.ttf)
# Generando caracteres para la fuente: Edu_AU_VIC_WA_NT_Dots (c:/tmp/content/ocr_fonts_latin\Edu_AU_VIC_WA_NT_Dots\Edu_AU_VIC_WA_NT_Dots-500.ttf)
# Generando caracteres para la fuente: Edu_AU_VIC_WA_NT_Guides (c:/tmp/content/ocr_fonts_latin\Edu_AU_VIC_WA_NT_Guides\Edu_AU_VIC_WA_NT_Guides-500.ttf)
# Generando caracteres para la fuente: Edu_AU_VIC_WA_NT_Hand (c:/tmp/content/ocr_fonts_latin\Edu_AU_VIC_WA_NT_Hand\Edu_AU_VIC_WA_NT_Hand-500.ttf)
# Generando caracteres para la fuente: Edu_AU_VIC_WA_NT_Pre (c:/tmp/content/ocr_fonts_latin\Edu_AU_VIC_WA_NT_Pre\Edu_AU_VIC_WA_NT_Pre-500.ttf)
# Generando caracteres para la fuente: Edu_NSW_ACT_Cursive (c:/tmp/content/ocr_fonts_latin\Edu_NSW_ACT_Cursive\Edu_NSW_ACT_Cursive-500.ttf)
# Generando caracteres para la fuente: Edu_NSW_ACT_Hand_Pre (c:/tmp/content/ocr_fonts_latin\Edu_NSW_ACT_Hand_Pre\Edu_NSW_ACT_Hand_Pre-500.ttf)
# Generando caracteres para la fuente: Edu_QLD_Hand (c:/tmp/content/ocr_fonts_latin\Edu_QLD_Hand\Edu_QLD_Hand-500.ttf)
# Generando caracteres para la fuente: Edu_SA_Hand (c:/tmp/content/ocr_fonts_latin\Edu_SA_Hand\Edu_SA_Hand-500.ttf)
# Generando caracteres para la fuente: Edu_VIC_WA_NT_Hand (c:/tmp/content/ocr_fonts_latin\Edu_VIC_WA_NT_Hand\Edu_VIC_WA_NT_Hand-500.ttf)
# Generando caracteres para la fuente: Edu_VIC_WA_NT_Hand_Pre (c:/tmp/content/ocr_fonts_latin\Edu_VIC_WA_NT_Hand_Pre\Edu_VIC_WA_NT_Hand_Pre-500.ttf)
# Generando caracteres para la fuente: Elsie (c:/tmp/content/ocr_fonts_latin\Elsie\Elsie-900.ttf)
# Generando caracteres para la fuente: Elsie_Swash_Caps (c:/tmp/content/ocr_fonts_latin\Elsie_Swash_Caps\Elsie_Swash_Caps-900.ttf)
# Generando caracteres para la fuente: El_Messiri (c:/tmp/content/ocr_fonts_latin\El_Messiri\El_Messiri-500.ttf)
# Generando caracteres para la fuente: Emblema_One (c:/tmp/content/ocr_fonts_latin\Emblema_One\Emblema_One-regular.ttf)
# Generando caracteres para la fuente: Emilys_Candy (c:/tmp/content/ocr_fonts_latin\Emilys_Candy\Emilys_Candy-regular.ttf)
# Generando caracteres para la fuente: Encode_Sans (c:/tmp/content/ocr_fonts_latin\Encode_Sans\Encode_Sans-100.ttf)
# Generando caracteres para la fuente: Encode_Sans_Condensed (c:/tmp/content/ocr_fonts_latin\Encode_Sans_Condensed\Encode_Sans_Condensed-100.ttf)
# Generando caracteres para la fuente: Encode_Sans_Expanded (c:/tmp/content/ocr_fonts_latin\Encode_Sans_Expanded\Encode_Sans_Expanded-100.ttf)
# Generando caracteres para la fuente: Encode_Sans_SC (c:/tmp/content/ocr_fonts_latin\Encode_Sans_SC\Encode_Sans_SC-100.ttf)
# Generando caracteres para la fuente: Encode_Sans_Semi_Condensed (c:/tmp/content/ocr_fonts_latin\Encode_Sans_Semi_Condensed\Encode_Sans_Semi_Condensed-100.ttf)
# Generando caracteres para la fuente: Encode_Sans_Semi_Expanded (c:/tmp/content/ocr_fonts_latin\Encode_Sans_Semi_Expanded\Encode_Sans_Semi_Expanded-100.ttf)
# Generando caracteres para la fuente: Engagement (c:/tmp/content/ocr_fonts_latin\Engagement\Engagement-regular.ttf)
# Generando caracteres para la fuente: Englebert (c:/tmp/content/ocr_fonts_latin\Englebert\Englebert-regular.ttf)
# Generando caracteres para la fuente: Enriqueta (c:/tmp/content/ocr_fonts_latin\Enriqueta\Enriqueta-500.ttf)
# Generando caracteres para la fuente: Ephesis (c:/tmp/content/ocr_fonts_latin\Ephesis\Ephesis-regular.ttf)
# Generando caracteres para la fuente: Epilogue (c:/tmp/content/ocr_fonts_latin\Epilogue\Epilogue-100.ttf)
# Generando caracteres para la fuente: Erica_One (c:/tmp/content/ocr_fonts_latin\Erica_One\Erica_One-regular.ttf)
# Generando caracteres para la fuente: Esteban (c:/tmp/content/ocr_fonts_latin\Esteban\Esteban-regular.ttf)
# Generando caracteres para la fuente: Estonia (c:/tmp/content/ocr_fonts_latin\Estonia\Estonia-regular.ttf)
# Generando caracteres para la fuente: Euphoria_Script (c:/tmp/content/ocr_fonts_latin\Euphoria_Script\Euphoria_Script-regular.ttf)
# Generando caracteres para la fuente: Ewert (c:/tmp/content/ocr_fonts_latin\Ewert\Ewert-regular.ttf)
# Generando caracteres para la fuente: Exile (c:/tmp/content/ocr_fonts_latin\Exile\Exile-regular.ttf)
# Generando caracteres para la fuente: Exo (c:/tmp/content/ocr_fonts_latin\Exo\Exo-100.ttf)
# Generando caracteres para la fuente: Exo_2 (c:/tmp/content/ocr_fonts_latin\Exo_2\Exo_2-100.ttf)
# Generando caracteres para la fuente: Expletus_Sans (c:/tmp/content/ocr_fonts_latin\Expletus_Sans\Expletus_Sans-500.ttf)
# Generando caracteres para la fuente: Explora (c:/tmp/content/ocr_fonts_latin\Explora\Explora-regular.ttf)
# Generando caracteres para la fuente: Faculty_Glyphic (c:/tmp/content/ocr_fonts_latin\Faculty_Glyphic\Faculty_Glyphic-regular.ttf)
# Generando caracteres para la fuente: Fahkwang (c:/tmp/content/ocr_fonts_latin\Fahkwang\Fahkwang-200.ttf)
# Generando caracteres para la fuente: Familjen_Grotesk (c:/tmp/content/ocr_fonts_latin\Familjen_Grotesk\Familjen_Grotesk-500.ttf)
# Generando caracteres para la fuente: Fanwood_Text (c:/tmp/content/ocr_fonts_latin\Fanwood_Text\Fanwood_Text-italic.ttf)
# Generando caracteres para la fuente: Farro (c:/tmp/content/ocr_fonts_latin\Farro\Farro-300.ttf)
# Generando caracteres para la fuente: Farsan (c:/tmp/content/ocr_fonts_latin\Farsan\Farsan-regular.ttf)
# Generando caracteres para la fuente: Fascinate (c:/tmp/content/ocr_fonts_latin\Fascinate\Fascinate-regular.ttf)
# Generando caracteres para la fuente: Fascinate_Inline (c:/tmp/content/ocr_fonts_latin\Fascinate_Inline\Fascinate_Inline-regular.ttf)
# Generando caracteres para la fuente: Faster_One (c:/tmp/content/ocr_fonts_latin\Faster_One\Faster_One-regular.ttf)
# Generando caracteres para la fuente: Fauna_One (c:/tmp/content/ocr_fonts_latin\Fauna_One\Fauna_One-regular.ttf)
# Generando caracteres para la fuente: Faustina (c:/tmp/content/ocr_fonts_latin\Faustina\Faustina-300.ttf)
# Generando caracteres para la fuente: Felipa (c:/tmp/content/ocr_fonts_latin\Felipa\Felipa-regular.ttf)
# Generando caracteres para la fuente: Fenix (c:/tmp/content/ocr_fonts_latin\Fenix\Fenix-regular.ttf)
# Generando caracteres para la fuente: Festive (c:/tmp/content/ocr_fonts_latin\Festive\Festive-regular.ttf)
# Generando caracteres para la fuente: Figtree (c:/tmp/content/ocr_fonts_latin\Figtree\Figtree-300.ttf)
# Generando caracteres para la fuente: Finlandica (c:/tmp/content/ocr_fonts_latin\Finlandica\Finlandica-500.ttf)
# Generando caracteres para la fuente: Fira_Code (c:/tmp/content/ocr_fonts_latin\Fira_Code\Fira_Code-300.ttf)
# Generando caracteres para la fuente: Fira_Mono (c:/tmp/content/ocr_fonts_latin\Fira_Mono\Fira_Mono-500.ttf)
# Generando caracteres para la fuente: Fira_Sans (c:/tmp/content/ocr_fonts_latin\Fira_Sans\Fira_Sans-100.ttf)
# Generando caracteres para la fuente: Fira_Sans_Condensed (c:/tmp/content/ocr_fonts_latin\Fira_Sans_Condensed\Fira_Sans_Condensed-100.ttf)
# Generando caracteres para la fuente: Fira_Sans_Extra_Condensed (c:/tmp/content/ocr_fonts_latin\Fira_Sans_Extra_Condensed\Fira_Sans_Extra_Condensed-100.ttf)
# Generando caracteres para la fuente: Fjalla_One (c:/tmp/content/ocr_fonts_latin\Fjalla_One\Fjalla_One-regular.ttf)
# Generando caracteres para la fuente: Flavors (c:/tmp/content/ocr_fonts_latin\Flavors\Flavors-regular.ttf)
# Generando caracteres para la fuente: Fleur_De_Leah (c:/tmp/content/ocr_fonts_latin\Fleur_De_Leah\Fleur_De_Leah-regular.ttf)
# Generando caracteres para la fuente: Flow_Block (c:/tmp/content/ocr_fonts_latin\Flow_Block\Flow_Block-regular.ttf)
# Generando caracteres para la fuente: Flow_Circular (c:/tmp/content/ocr_fonts_latin\Flow_Circular\Flow_Circular-regular.ttf)
# Generando caracteres para la fuente: Flow_Rounded (c:/tmp/content/ocr_fonts_latin\Flow_Rounded\Flow_Rounded-regular.ttf)
# Generando caracteres para la fuente: Foldit (c:/tmp/content/ocr_fonts_latin\Foldit\Foldit-100.ttf)
# Generando caracteres para la fuente: Fondamento (c:/tmp/content/ocr_fonts_latin\Fondamento\Fondamento-italic.ttf)
# Generando caracteres para la fuente: Forum (c:/tmp/content/ocr_fonts_latin\Forum\Forum-regular.ttf)
# Generando caracteres para la fuente: Fragment_Mono (c:/tmp/content/ocr_fonts_latin\Fragment_Mono\Fragment_Mono-italic.ttf)
# Generando caracteres para la fuente: Francois_One (c:/tmp/content/ocr_fonts_latin\Francois_One\FrancoisOne-Regular.ttf)
# Generando caracteres para la fuente: Frank_Ruhl_Libre (c:/tmp/content/ocr_fonts_latin\Frank_Ruhl_Libre\Frank_Ruhl_Libre-300.ttf)
# Generando caracteres para la fuente: Fraunces (c:/tmp/content/ocr_fonts_latin\Fraunces\Fraunces-100.ttf)
# Generando caracteres para la fuente: Freckle_Face (c:/tmp/content/ocr_fonts_latin\Freckle_Face\Freckle_Face-regular.ttf)
# Generando caracteres para la fuente: Fredericka_the_Great (c:/tmp/content/ocr_fonts_latin\Fredericka_the_Great\Fredericka_the_Great-regular.ttf)
# Generando caracteres para la fuente: Fredoka (c:/tmp/content/ocr_fonts_latin\Fredoka\Fredoka-300.ttf)
# Generando caracteres para la fuente: Freeman (c:/tmp/content/ocr_fonts_latin\Freeman\Freeman-regular.ttf)
# Generando caracteres para la fuente: Fresca (c:/tmp/content/ocr_fonts_latin\Fresca\Fresca-regular.ttf)
# Generando caracteres para la fuente: Fruktur (c:/tmp/content/ocr_fonts_latin\Fruktur\Fruktur-italic.ttf)
# Generando caracteres para la fuente: Fuggles (c:/tmp/content/ocr_fonts_latin\Fuggles\Fuggles-regular.ttf)
# Generando caracteres para la fuente: Funnel_Display (c:/tmp/content/ocr_fonts_latin\Funnel_Display\Funnel_Display-300.ttf)
# Generando caracteres para la fuente: Funnel_Sans (c:/tmp/content/ocr_fonts_latin\Funnel_Sans\Funnel_Sans-300.ttf)
# Generando caracteres para la fuente: Fustat (c:/tmp/content/ocr_fonts_latin\Fustat\Fustat-200.ttf)
# Generando caracteres para la fuente: Fuzzy_Bubbles (c:/tmp/content/ocr_fonts_latin\Fuzzy_Bubbles\Fuzzy_Bubbles-700.ttf)
# Generando caracteres para la fuente: Gabarito (c:/tmp/content/ocr_fonts_latin\Gabarito\Gabarito-500.ttf)
# Generando caracteres para la fuente: Gabriela (c:/tmp/content/ocr_fonts_latin\Gabriela\Gabriela-regular.ttf)
# Generando caracteres para la fuente: Gafata (c:/tmp/content/ocr_fonts_latin\Gafata\Gafata-regular.ttf)
# Generando caracteres para la fuente: Gajraj_One (c:/tmp/content/ocr_fonts_latin\Gajraj_One\Gajraj_One-regular.ttf)
# Generando caracteres para la fuente: Galindo (c:/tmp/content/ocr_fonts_latin\Galindo\Galindo-regular.ttf)
# Generando caracteres para la fuente: Gantari (c:/tmp/content/ocr_fonts_latin\Gantari\Gantari-100.ttf)
# Generando caracteres para la fuente: Gasoek_One (c:/tmp/content/ocr_fonts_latin\Gasoek_One\Gasoek_One-regular.ttf)
# Generando caracteres para la fuente: Ga_Maamli (c:/tmp/content/ocr_fonts_latin\Ga_Maamli\Ga_Maamli-regular.ttf)
# Generando caracteres para la fuente: Geist (c:/tmp/content/ocr_fonts_latin\Geist\Geist-100.ttf)
# ...
# Generando caracteres para la fuente: Noto_Sans_Carian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Carian\Noto_Sans_Carian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Caucasian_Albanian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Caucasian_Albanian\Noto_Sans_Caucasian_Albanian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Chakma (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Chakma\Noto_Sans_Chakma-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Cham (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Cham\Noto_Sans_Cham-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Cherokee (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Cherokee\Noto_Sans_Cherokee-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Chorasmian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Chorasmian\Noto_Sans_Chorasmian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Coptic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Coptic\Noto_Sans_Coptic-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Cuneiform (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Cuneiform\Noto_Sans_Cuneiform-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Cypriot (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Cypriot\Noto_Sans_Cypriot-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Cypro_Minoan (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Cypro_Minoan\Noto_Sans_Cypro_Minoan-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Deseret (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Deseret\Noto_Sans_Deseret-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Devanagari (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Devanagari\Noto_Sans_Devanagari-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Display (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Display\Noto_Sans_Display-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Duployan (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Duployan\Noto_Sans_Duployan-700.ttf)
# Generando caracteres para la fuente: Noto_Sans_Egyptian_Hieroglyphs (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Egyptian_Hieroglyphs\Noto_Sans_Egyptian_Hieroglyphs-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Elbasan (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Elbasan\Noto_Sans_Elbasan-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Elymaic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Elymaic\Noto_Sans_Elymaic-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Ethiopic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Ethiopic\Noto_Sans_Ethiopic-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Georgian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Georgian\Noto_Sans_Georgian-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Glagolitic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Glagolitic\Noto_Sans_Glagolitic-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Gothic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Gothic\Noto_Sans_Gothic-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Grantha (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Grantha\Noto_Sans_Grantha-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Gujarati (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Gujarati\Noto_Sans_Gujarati-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Gunjala_Gondi (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Gunjala_Gondi\Noto_Sans_Gunjala_Gondi-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_Gurmukhi (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Gurmukhi\Noto_Sans_Gurmukhi-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Hanifi_Rohingya (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Hanifi_Rohingya\Noto_Sans_Hanifi_Rohingya-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_Hanunoo (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Hanunoo\Noto_Sans_Hanunoo-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Hatran (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Hatran\Noto_Sans_Hatran-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Hebrew (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Hebrew\Noto_Sans_Hebrew-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_HK (c:/tmp/content/ocr_fonts_latin\Noto_Sans_HK\Noto_Sans_HK-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Imperial_Aramaic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Imperial_Aramaic\Noto_Sans_Imperial_Aramaic-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Indic_Siyaq_Numbers (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Indic_Siyaq_Numbers\Noto_Sans_Indic_Siyaq_Numbers-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Inscriptional_Pahlavi (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Inscriptional_Pahlavi\Noto_Sans_Inscriptional_Pahlavi-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Inscriptional_Parthian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Inscriptional_Parthian\Noto_Sans_Inscriptional_Parthian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Javanese (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Javanese\Noto_Sans_Javanese-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_JP (c:/tmp/content/ocr_fonts_latin\Noto_Sans_JP\Noto_Sans_JP-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Kaithi (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Kaithi\Noto_Sans_Kaithi-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Kannada (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Kannada\Noto_Sans_Kannada-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Kawi (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Kawi\Noto_Sans_Kawi-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_Kayah_Li (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Kayah_Li\Noto_Sans_Kayah_Li-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_Kharoshthi (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Kharoshthi\Noto_Sans_Kharoshthi-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Khmer (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Khmer\Noto_Sans_Khmer-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Khojki (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Khojki\Noto_Sans_Khojki-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Khudawadi (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Khudawadi\Noto_Sans_Khudawadi-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_KR (c:/tmp/content/ocr_fonts_latin\Noto_Sans_KR\Noto_Sans_KR-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Lao (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Lao\Noto_Sans_Lao-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Lao_Looped (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Lao_Looped\Noto_Sans_Lao_Looped-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Lepcha (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Lepcha\Noto_Sans_Lepcha-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Limbu (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Limbu\Noto_Sans_Limbu-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Linear_A (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Linear_A\Noto_Sans_Linear_A-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Linear_B (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Linear_B\Noto_Sans_Linear_B-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Lisu (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Lisu\Noto_Sans_Lisu-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_Lydian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Lydian\Noto_Sans_Lydian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Mahajani (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Mahajani\Noto_Sans_Mahajani-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Malayalam (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Malayalam\Noto_Sans_Malayalam-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Mandaic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Mandaic\Noto_Sans_Mandaic-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Manichaean (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Manichaean\Noto_Sans_Manichaean-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Marchen (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Marchen\Noto_Sans_Marchen-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Masaram_Gondi (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Masaram_Gondi\Noto_Sans_Masaram_Gondi-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Mayan_Numerals (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Mayan_Numerals\Noto_Sans_Mayan_Numerals-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Medefaidrin (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Medefaidrin\Noto_Sans_Medefaidrin-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_Meetei_Mayek (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Meetei_Mayek\Noto_Sans_Meetei_Mayek-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Mende_Kikakui (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Mende_Kikakui\Noto_Sans_Mende_Kikakui-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Meroitic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Meroitic\Noto_Sans_Meroitic-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Miao (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Miao\Noto_Sans_Miao-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Modi (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Modi\Noto_Sans_Modi-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Mongolian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Mongolian\Noto_Sans_Mongolian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Mono (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Mono\Noto_Sans_Mono-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Mro (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Mro\Noto_Sans_Mro-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Multani (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Multani\Noto_Sans_Multani-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Nabataean (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Nabataean\Noto_Sans_Nabataean-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Nag_Mundari (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Nag_Mundari\Noto_Sans_Nag_Mundari-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_Nandinagari (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Nandinagari\Noto_Sans_Nandinagari-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Newa (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Newa\Noto_Sans_Newa-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_New_Tai_Lue (c:/tmp/content/ocr_fonts_latin\Noto_Sans_New_Tai_Lue\Noto_Sans_New_Tai_Lue-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_NKo (c:/tmp/content/ocr_fonts_latin\Noto_Sans_NKo\Noto_Sans_NKo-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_NKo_Unjoined (c:/tmp/content/ocr_fonts_latin\Noto_Sans_NKo_Unjoined\Noto_Sans_NKo_Unjoined-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_Nushu (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Nushu\Noto_Sans_Nushu-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Ogham (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Ogham\Noto_Sans_Ogham-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Old_Hungarian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Old_Hungarian\Noto_Sans_Old_Hungarian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Old_Italic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Old_Italic\Noto_Sans_Old_Italic-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Old_North_Arabian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Old_North_Arabian\Noto_Sans_Old_North_Arabian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Old_Permic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Old_Permic\Noto_Sans_Old_Permic-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Old_Persian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Old_Persian\Noto_Sans_Old_Persian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Old_Sogdian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Old_Sogdian\Noto_Sans_Old_Sogdian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Old_South_Arabian (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Old_South_Arabian\Noto_Sans_Old_South_Arabian-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Old_Turkic (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Old_Turkic\Noto_Sans_Old_Turkic-regular.ttf)
# Generando caracteres para la fuente: Noto_Sans_Ol_Chiki (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Ol_Chiki\Noto_Sans_Ol_Chiki-500.ttf)
# Generando caracteres para la fuente: Noto_Sans_Oriya (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Oriya\Noto_Sans_Oriya-100.ttf)
# Generando caracteres para la fuente: Noto_Sans_Osage (c:/tmp/content/ocr_fonts_latin\Noto_Sans_Osage\Noto_Sans_Osage-regular.ttf)
# Generando caracteres para la fuente: Nova_Mono (c:/tmp/content/ocr_fonts_latin\Nova_Mono\Nova_Mono-regular.ttf)
# Generando caracteres para la fuente: Overpass_Mono (c:/tmp/content/ocr_fonts_latin\Overpass_Mono\Overpass_Mono-300.ttf)
# Generando caracteres para la fuente: Oxygen_Mono (c:/tmp/content/ocr_fonts_latin\Oxygen_Mono\Oxygen_Mono-regular.ttf)
# Generando caracteres para la fuente: Petit_Formal_Script (c:/tmp/content/ocr_fonts_latin\Petit_Formal_Script\PetitFormalScript-Regular.ttf)
# Generando caracteres para la fuente: PT_Mono (c:/tmp/content/ocr_fonts_latin\PT_Mono\PT_Mono-regular.ttf)
# Generando caracteres para la fuente: PT_Serif_Caption (c:/tmp/content/ocr_fonts_latin\PT_Serif_Caption\PTSerifCaption-Italic.ttf)
# Generando caracteres para la fuente: Rakkas (c:/tmp/content/ocr_fonts_latin\Rakkas\Rakkas-Regular.ttf)
# Generando caracteres para la fuente: Rammetto_One (c:/tmp/content/ocr_fonts_latin\Rammetto_One\RammettoOne-Regular.ttf)
# Generando caracteres para la fuente: Reddit_Mono (c:/tmp/content/ocr_fonts_latin\Reddit_Mono\Reddit_Mono-200.ttf)
# Generando caracteres para la fuente: Red_Hat_Mono (c:/tmp/content/ocr_fonts_latin\Red_Hat_Mono\Red_Hat_Mono-300.ttf)
# Generando caracteres para la fuente: Roboto_Mono (c:/tmp/content/ocr_fonts_latin\Roboto_Mono\Roboto-Black.ttf)
# Generando caracteres para la fuente: Sixtyfour (c:/tmp/content/ocr_fonts_latin\Sixtyfour\Sixtyfour-regular.ttf)
# Generando caracteres para la fuente: Sixtyfour_Convergence (c:/tmp/content/ocr_fonts_latin\Sixtyfour_Convergence\Sixtyfour_Convergence-regular.ttf)
# Generando caracteres para la fuente: Sometype_Mono (c:/tmp/content/ocr_fonts_latin\Sometype_Mono\Sometype_Mono-500.ttf)
# Generando caracteres para la fuente: Source_Code_Pro (c:/tmp/content/ocr_fonts_latin\Source_Code_Pro\Source_Code_Pro-200.ttf)
# Generando caracteres para la fuente: Space_Mono (c:/tmp/content/ocr_fonts_latin\Space_Mono\Space_Mono-700.ttf)
# Generando caracteres para la fuente: Spline_Sans_Mono (c:/tmp/content/ocr_fonts_latin\Spline_Sans_Mono\Spline_Sans_Mono-300.ttf)
# Generando caracteres para la fuente: Syne_Mono (c:/tmp/content/ocr_fonts_latin\Syne_Mono\Syne_Mono-regular.ttf)
# Generando caracteres para la fuente: Ubuntu_Mono (c:/tmp/content/ocr_fonts_latin\Ubuntu_Mono\Ubuntu_Mono-700.ttf)
# Generando caracteres para la fuente: Ubuntu_Sans_Mono (c:/tmp/content/ocr_fonts_latin\Ubuntu_Sans_Mono\Ubuntu_Sans_Mono-500.ttf)
# Generando caracteres para la fuente: Victor_Mono (c:/tmp/content/ocr_fonts_latin\Victor_Mono\Victor_Mono-100.ttf)
# Generando caracteres para la fuente: VT323 (c:/tmp/content/ocr_fonts_latin\VT323\VT323-regular.ttf)
# Generando caracteres para la fuente: Xanh_Mono (c:/tmp/content/ocr_fonts_latin\Xanh_Mono\Xanh_Mono-italic.ttf)
#
# Generación de datasets completada.
#
# Dataset de NumPy (estructura):
# [('image', 'O'), ('bbox', 'O'), ('index', '<i8')]
# Número total de entradas en NumPy dataset: 328692
#
# Dataset de Pandas (primeras 5 filas):
#    index character font_type background_type character_color
# 0      0         A   ABeeZee           negro          blanco
# 1      1         A   ABeeZee            blur          blanco
# 2      2         A   ABeeZee          rotate          blanco
# 3      3         A   ABeeZee          rotate          blanco
# 4      4         B   ABeeZee           negro          blanco
# Número total de entradas en Pandas dataset: 328692

# %%
muestra = pandas_dataset.sample(10)
for index, row in muestra.iterrows():
    print(f"Index: {row['index']}, Character: {row['character']}, Font Type: {row['font_type']}, Background Type: {row['background_type']}, Character Color: {row['character_color']}")
    img_muestra = numpy_dataset[row['index']]['image']
    bbox= numpy_dataset[row['index']]['bbox']
    cv2.rectangle(img_muestra, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (128, 128, 128), 1)
    plt.imshow(img_muestra, cmap='gray')
    plt.show()
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 muestra = pandas_dataset.sample(10)
#       2 for index, row in muestra.iterrows():
#       3     print(f"Index: {row['index']}, Character: {row['character']}, Font Type: {row['font_type']}, Background Type: {row['background_type']}, Character Color: {row['character_color']}")
#
# NameError: name 'pandas_dataset' is not defined

# %% [markdown]
# ## Dataset de entrenamiento
# Este dataset contendra imagenes de carcateres y las coordenadas de la caja que los contiene

# %%
#composed_numpy_dataset = np.load('c:/tmp/content/ocr_composed_images_dataset.npy', allow_pickle=True)

# %%
composed_numpy_dataset = numpy_dataset
composed_pandas_dataset = pandas_dataset

# %% [markdown]
# ## Generacion de archivos de entrenamiento

# %%
# Configuración del archivo data.yaml para YOLOv8
characters_to_generate = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789"
class_id_to_char = {i: char for i, char in enumerate(characters_to_generate)}
names_string = "["
for char in characters_to_generate:
    if char == characters_to_generate[-1]:
        names_string += f"'{char}'"
    else:
        names_string += f"'{char}', "
names_string += "]"

# Configuración del archivo data.yaml para YOLOv8
with open("data.yaml", "w", encoding="utf-8") as f:
    f.write(f"""
path: c:/tmp/content/training
train: images/train
val: images/val
names: {names_string}
""")

# Generar el diccionario propio con ID y letra
class_id_to_char = {i: char for i, char in enumerate(characters_to_generate)}


def get_id_by_char(char):
    """
    Busca el ID de clase dado un carácter, iterando directamente sobre el diccionario.
    Devuelve el ID si se encuentra, None si el carácter no está en las clases.
    """
    for class_id, stored_char in class_id_to_char.items():
        if stored_char == char:
            return class_id
    return None # Si el carácter no se encontró después de buscar en todo el diccionario

def get_char_by_id(class_id):
    return class_id_to_char.get(class_id)

# %%
os.makedirs('c:/tmp/content/training/images/train', exist_ok=True)
os.makedirs('c:/tmp/content/training/images/val', exist_ok=True)
os.makedirs('c:/tmp/content/training/labels/train', exist_ok=True)
os.makedirs('c:/tmp/content/training/labels/val', exist_ok=True)

# Obtener el número total de muestras
num_samples = len(composed_numpy_dataset['image'])
indices = list(range(num_samples)) # Generar índices de 0 a num_samples-1
train_idx, val_idx = train_test_split(indices, test_size=0.1, random_state=42)

def save_image_and_label(idx, image, labels_list, bboxes_list, split):
    """
    Guarda una imagen y su archivo de etiquetas en formato YOLO.

    Args:
        idx (int): Índice de la imagen (usado para el nombre del archivo).
        image (np.array): Datos de la imagen (en escala de grises, asumido 0-1 o 0-255).
        bboxes_list (list): Lista de bounding boxes para la imagen.
                            Cada bbox es una lista/tupla [x_min, y_min, x_max, y_max].
                            Puede estar vacía si no hay caracteres.
        split (str): 'train' o 'val', para determinar el directorio de destino.
    """
    img_path = f'c:/tmp/content/training/images/{split}/{idx}.jpg'
    label_path = f'c:/tmp/content/training/labels/{split}/{idx}.txt'


    # Obtener las dimensiones de la imagen guardada para la normalización
    h, w = image.shape # Asume que la imagen es 2D (escala de grises)
    img_to_save = Image.fromarray((image * 255).astype('uint8')).convert('L')
    img_to_save.save(img_path)

    # Abre el archivo de etiquetas para escribir las coordenadas de todos los bboxes
    with open(label_path, 'w') as f:
        for label, bbox in zip(labels_list, bboxes_list):
            x_min, y_min, x_max, y_max = bbox

            # Formato YOLO: class x_center y_center width height (normalizado)
            xc = (x_min + x_max) / 2 / w
            yc = (y_min + y_max) / 2 / h
            bw = (x_max - x_min) / w
            bh = (y_max - y_min) / h

            label_id = get_id_by_char(label)
            if label_id is None:
                print(f"Advertencia: El carácter '{label}' no se encontró en las clases. Saltando.")
                continue

            f.write(f'{label_id} {xc:.6f} {yc:.6f} {bw:.6f} {bh:.6f}\n')


# Bucle principal para procesar y guardar imágenes y etiquetas
# CAMBIO PRINCIPAL: Iteración sobre los índices directamente y acceso al dataset NumPy
total = len(indices)
contador = 1
for idx in indices: # Iteramos sobre la lista de índices generada
    split = 'train' if idx in train_idx else 'val'
    if (contador * 100) % total == 0:
        print(f"{contador * 100 / total}% completado.")
    contador += 1

    # Accedemos a la imagen y su lista de bboxes usando el índice actual
    current_image = composed_numpy_dataset['image'][idx]
    current_bboxes = [composed_numpy_dataset['bbox'][idx]]
    index = composed_numpy_dataset['index'][idx]
    current_data = composed_pandas_dataset[composed_pandas_dataset['index'] == index].iloc[0]
    if current_data.empty:
        print(f"Advertencia: No se encontraron datos para el índice {index}. Saltando.")
    current_labels = [current_data['character']]

    save_image_and_label(idx, current_image, current_labels, current_bboxes, split)
# Out:
# 25.0% completado.
# 50.0% completado.
# 75.0% completado.
# 100.0% completado.

# %%
import os

# Asegúrate de que 'characters_to_generate' sea exactamente la misma cadena
# que utilizaste para generar tu data.yaml
characters_to_generate = "ABCDEFGHIJKLMNOPQRSTUVWXYZÑabcdefghijklmnopqrstuvwxyzñáéíóúü0123456789.,;:?¿!¡-—&*/+=-_@#$%"
num_classes = len(characters_to_generate)
max_valid_id = num_classes - 1

# Asegúrate de que estas rutas son correctas y accesibles en tu sistema
label_dirs = [
    'c:/tmp/content/training/labels/train',
    'c:/tmp/content/training/labels/val'
]

print(f"Verificando etiquetas. Número de clases esperado: {num_classes} (IDs 0 a {max_valid_id})")

errors_found = False

for label_dir in label_dirs:
    print(f"\n--- Procesando directorio: {label_dir} ---")
    if not os.path.exists(label_dir):
        print(f"Advertencia: Directorio no encontrado: {label_dir}. Omite este directorio.")
        continue

    txt_files = [f for f in os.listdir(label_dir) if f.endswith('.txt')]
    if not txt_files:
        print(f"No se encontraron archivos .txt en {label_dir}.")
        continue

    for label_file in txt_files:
        file_path = os.path.join(label_dir, label_file)
        try:
            with open(file_path, 'r', encoding='utf-8') as f: # Añadir encoding='utf-8' por si hay caracteres especiales en las rutas o nombres
                for line_num, line in enumerate(f):
                    parts = line.strip().split()

                    # 1. Verificar si la línea está vacía
                    if not parts:
                        continue # Ignorar líneas completamente vacías

                    # 2. Verificar la cantidad correcta de valores
                    if len(parts) != 5:
                        print(f"ERROR: Cantidad incorrecta de valores en {label_file} línea {line_num+1}.")
                        print(f"  Contenido: '{line.strip()}' (Esperado: 5 valores: class_id cx cy w h)")
                        errors_found = True
                        continue # Pasa a la siguiente línea

                    try:
                        class_id = int(parts[0])

                        # 3. Verificar el rango del ID de clase
                        if not (0 <= class_id <= max_valid_id):
                            print(f"ERROR: ID de clase '{class_id}' fuera de rango en {label_file} línea {line_num+1}.")
                            print(f"  Rango válido para ID de clase: 0 a {max_valid_id}.")
                            errors_found = True

                        # 4. Verificar el rango de las coordenadas
                        # Las coordenadas son cx, cy, w, h (índices 1 a 4)
                        for i in range(1, 5):
                            val_str = parts[i]
                            val = float(val_str)
                            if not (0.0 <= val <= 1.0):
                                print(f"ERROR: Coordenada '{val_str}' fuera de rango [0.0, 1.0] en {label_file} línea {line_num+1} (posición {i}).")
                                errors_found = True
                            # Opcional: También podrías querer verificar si width o height son 0 o extremadamente pequeños
                            if i in [3, 4] and val < 0.0001: # Check for width/height being too small
                                print(f"ADVERTENCIA: Ancho/Alto muy pequeño ({val_str}) en {label_file} línea {line_num+1} (posición {i}).")

                    except ValueError:
                        print(f"ERROR: Error de tipo de dato (no numérico) en {label_file} línea {line_num+1}.")
                        print(f"  Contenido: '{line.strip()}'")
                        errors_found = True
                    except IndexError: # En caso de que split() devuelva menos elementos de lo esperado inesperadamente
                        print(f"ERROR: Error de índice al procesar línea {line_num+1} en {label_file}.")
                        print(f"  Contenido: '{line.strip()}'")
                        errors_found = True

        except FileNotFoundError:
            print(f"ERROR: Archivo no encontrado: {file_path}")
            errors_found = True
        except Exception as e:
            print(f"ERROR: Error inesperado al leer el archivo {file_path}: {e}")
            errors_found = True

print("\n--- Verificación de etiquetas completada ---")
if errors_found:
    print("¡Se encontraron errores! Por favor, revisa los mensajes de ERROR y corrige tus archivos de etiquetas.")
    print("Recuerda usar 'CUDA_LAUNCH_BLOCKING=1' para depurar el entrenamiento de YOLOv8 si el problema persiste.")
else:
    print("¡No se encontraron errores ni advertencias importantes en las etiquetas!")
# Out:
# Verificando etiquetas. Número de clases esperado: 91 (IDs 0 a 90)
#
# --- Procesando directorio: c:/tmp/content/training/labels/train ---
#
# --- Procesando directorio: c:/tmp/content/training/labels/val ---
#
# --- Verificación de etiquetas completada ---
# ¡No se encontraron errores ni advertencias importantes en las etiquetas!

# %% [markdown]
# ## Entrenamiento del Modelo YOLO 8

# %%
model = YOLO('yolov8n.pt')
model.train(
    data='data.yaml',
    epochs=10,
    imgsz=256,
    batch=64,
    workers=8,
    show=False,
    augment=False
)

print("Entrenamiento del modelo YOLOv8 completado.")
# Out:
# New https://pypi.org/project/ultralytics/8.3.158 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.155  Python-3.9.23 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=256, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train12, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train12, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=91
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    998611  ultralytics.nn.modules.head.Detect           [91, [64, 128, 256]]
# Model summary: 129 layers, 3,258,147 parameters, 3,258,131 gradients, 9.3 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.30.2 ms, read: 9.53.7 MB/s, size: 4.2 KB)
# train: Scanning C:\tmp\content\training\labels\train... 295822 images, 0 backgrounds, 0 corrupt: 100%|██████████| 29582
# train: New cache created: C:\tmp\content\training\labels\train.cache
# val: Fast image access  (ping: 0.20.2 ms, read: 5.31.9 MB/s, size: 3.9 KB)
# val: Scanning C:\tmp\content\training\labels\val... 32870 images, 0 backgrounds, 0 corrupt: 100%|██████████| 32870/3287
# val: New cache created: C:\tmp\content\training\labels\val.cache
# Plotting labels to runs\detect\train12\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 256 train, 256 val
# Using 8 dataloader workers
# Logging results to runs\detect\train12
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      1.44G     0.3287      1.802     0.8151         14        256: 100%|██████████| 4623/4623 [21:00<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870      0.873       0.87      0.912      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      2.02G      0.277     0.7723     0.7964         14        256: 100%|██████████| 4623/4623 [20:52<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870      0.852      0.865      0.913      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      2.02G      0.273     0.6379     0.7954         14        256: 100%|██████████| 4623/4623 [20:59<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870      0.902      0.906      0.938      0.916
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      2.02G      0.244     0.5278     0.7886         14        256: 100%|██████████| 4623/4623 [20:48<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870      0.913      0.922      0.949      0.934
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      2.02G     0.2109     0.4474     0.7819         14        256: 100%|██████████| 4623/4623 [21:06<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870      0.914      0.922      0.951      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      2.02G     0.1928     0.4026     0.7783         14        256: 100%|██████████| 4623/4623 [21:03<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870      0.918      0.928      0.955      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      2.02G     0.1794     0.3685     0.7753         14        256: 100%|██████████| 4623/4623 [21:04<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870       0.92      0.932      0.958      0.947
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      2.02G     0.1669     0.3355     0.7728         14        256: 100%|██████████| 4623/4623 [21:05<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870      0.923      0.939      0.962      0.953
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      2.02G     0.1547     0.3032     0.7708         14        256: 100%|██████████| 4623/4623 [20:50<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870      0.926      0.944      0.965      0.958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      2.02G     0.1416     0.2682     0.7685         14        256: 100%|██████████| 4623/4623 [20:58<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870      0.929      0.948      0.968      0.962
#
# 10 epochs completed in 4.121 hours.
# Optimizer stripped from runs\detect\train12\weights\last.pt, 6.7MB
# Optimizer stripped from runs\detect\train12\weights\best.pt, 6.7MB
#
# Validating runs\detect\train12\weights\best.pt...
# Ultralytics 8.3.155  Python-3.9.23 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# Model summary (fused): 72 layers, 3,252,785 parameters, 0 gradients, 9.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 257/257 [03:
#                    all      32870      32870       0.93      0.948      0.968      0.962
#                      A        359        359      0.959      0.994      0.987      0.986
#                      B        375        375      0.921      0.981      0.979      0.977
#                      C        387        387      0.948      0.891      0.972      0.971
#                      D        372        372      0.928      0.995      0.986      0.985
#                      E        382        382      0.924      0.992       0.97      0.968
#                      F        393        393      0.939       0.98      0.983      0.978
#                      G        392        392      0.934      0.982      0.977      0.977
#                      H        365        365      0.927      0.962      0.979      0.978
#                      I        393        393      0.781      0.783      0.881      0.861
#                      J        340        340      0.849      0.959      0.962       0.96
#                      K        343        343      0.932      0.988      0.982      0.981
#                      L        352        352      0.936      0.986      0.985      0.984
#                      M        384        384      0.938      0.981      0.981      0.981
#                      N        358        358      0.913      0.991      0.981      0.979
#                      O        350        350      0.789      0.691      0.826      0.826
#                      P        341        341      0.924      0.953      0.979      0.978
#                      Q        348        348      0.935      0.988      0.991      0.991
#                      R        375        375      0.944      0.995      0.985      0.984
#                      S        416        416      0.931      0.921      0.969      0.969
#                      T        341        341       0.94      0.994      0.984      0.984
#                      U        348        348      0.907      0.963      0.982      0.982
#                      V        353        353      0.936      0.895      0.952      0.952
#                      W        364        364      0.946      0.923      0.977      0.977
#                      X        370        370      0.967       0.95      0.981      0.981
#                      Y        351        351      0.939       0.96      0.983      0.983
#                      Z        366        366      0.949      0.909      0.972      0.969
#                              332        332      0.934      0.984      0.983      0.982
#                      a        359        359       0.98      0.958      0.988      0.988
#                      b        356        356      0.684      0.881      0.863      0.863
#                      c        368        368      0.874       0.96      0.968      0.967
#                      d        350        350       0.67      0.917      0.918      0.915
#                      e        350        350      0.969      0.931      0.981       0.98
#                      f        355        355      0.979      0.935      0.983       0.98
#                      g        371        371       0.97      0.908      0.976      0.976
#                      h        375        375      0.984      0.933      0.988      0.985
#                      i        335        335      0.788      0.866      0.922      0.898
#                      j        344        344      0.984       0.93      0.985       0.98
#                      k        342        342      0.995      0.942      0.986      0.982
#                      l        358        358      0.695      0.758      0.808      0.789
#                      m        355        355      0.974      0.927      0.985      0.984
#                      n        363        363      0.962      0.939      0.985      0.985
#                      o        380        380        0.8      0.946      0.911       0.91
#                      p        329        329      0.614      0.909      0.801      0.801
#                      q        366        366      0.641      0.893      0.831       0.83
#                      r        374        374      0.978      0.935      0.984      0.983
#                      s        368        368      0.881      0.929      0.961      0.961
#                      t        353        353          1      0.948      0.992      0.991
#                      u        358        358      0.927      0.953      0.981      0.981
#                      v        359        359      0.883      0.933      0.944      0.943
#                      w        334        334      0.872      0.946      0.962      0.962
#                      x        368        368      0.895      0.976      0.974      0.973
#                      y        389        389       0.96      0.956      0.988      0.988
#                      z        355        355      0.876      0.966      0.966      0.965
#                              371        371      0.978       0.94      0.988      0.987
#                              375        375          1      0.989      0.995      0.995
#                              344        344      0.992      0.991      0.995      0.995
#                              381        381      0.981      0.987      0.994      0.988
#                              360        360      0.985      0.992      0.992      0.992
#                              356        356      0.998      0.978      0.994      0.993
#                              351        351      0.995       0.98      0.994      0.994
#                      0        357        357      0.716      0.776      0.776      0.776
#                      1        364        364      0.909      0.883      0.953       0.95
#                      2        395        395       0.98      0.979      0.992      0.991
#                      3        396        396       0.97      0.986      0.991       0.99
#                      4        344        344      0.993      0.988      0.995      0.994
#                      5        366        366      0.981      0.988      0.994      0.994
#                      6        352        352       0.98       0.98      0.994      0.994
#                      7        329        329      0.984      0.985      0.994      0.993
#                      8        384        384      0.987       0.99      0.995      0.994
#                      9        352        352       0.94      0.974      0.987      0.987
#                      .        340        340      0.976      0.961      0.991      0.925
#                      ,        334        334      0.979      0.969      0.993      0.962
#                      ;        408        408      0.985       0.99      0.995      0.977
#                      :        347        347       0.98      0.988       0.99      0.973
#                      ?        371        371      0.996          1      0.995      0.994
#                              341        341      0.996      0.988      0.993      0.993
#                      !        364        364      0.991      0.986      0.991      0.974
#                              372        372      0.946      0.807      0.957      0.941
#                      -        755        755      0.943      0.943      0.968      0.875
#                              366        366      0.942       0.85      0.938      0.856
#                      &        336        336      0.988      0.979      0.992      0.992
#                      *        363        363      0.992      0.989      0.995      0.993
#                      /        362        362      0.955      0.972      0.986      0.986
#                      +        373        373      0.981      0.987       0.99      0.987
#                      =        330        330      0.982      0.982      0.992      0.985
#                      _        371        371      0.988      0.915      0.981      0.905
#                      @        328        328      0.994      0.993      0.995      0.995
#                      #        364        364      0.994      0.979      0.995      0.995
#                      $        349        349      0.988      0.982      0.993      0.992
#                      %        355        355      0.987      0.989      0.994      0.994
# Speed: 0.0ms preprocess, 0.7ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs\detect\train12
# Entrenamiento del modelo YOLOv8 completado.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# --- Configura la ruta de tu directorio de resultados ---
# Puedes encontrar el nombre de la carpeta de la última ejecución en la salida de tu entrenamiento.
# Por ejemplo, si tu entrenamiento más reciente guardó los resultados en 'runs/detect/train', usa eso.
# Si estás ejecutando esto inmediatamente después de entrenar, el directorio 'train' será el más reciente.
# Si hay múltiples 'trainX' carpetas, ajusta 'run_dir_name' a la correcta.
# Por ejemplo, si el último fue 'train3', sería 'train3'.
run_dir_name = 'train10' # O 'train2', 'train3', etc., según tu última ejecución.
results_path = f'C:/Users/Andres/runs/detect/{run_dir_name}/results.csv'

# Comprueba si el archivo existe antes de intentar leerlo
if not os.path.exists(results_path):
    print(f"Error: El archivo de resultados no se encontró en '{results_path}'.")
    print("Asegúrate de que la ruta sea correcta y que el entrenamiento haya finalizado.")
    print("Revisa los nombres de las carpetas en 'c:/tmp/content/runs/detect/' para encontrar la correcta.")
else:
    # Cargar los resultados en un DataFrame de pandas
    # Los resultados.csv de YOLOv8 tienen la cabecera comentada con #, así que la omitimos.
    # También hay un espacio extra antes de los nombres de columna, lo removemos.
    df_results = pd.read_csv(results_path, skipinitialspace=True)

    # Limpiar los nombres de las columnas para facilitar el acceso
    # Las columnas suelen ser como '                 metrics/precision(B)'
    df_results.columns = df_results.columns.str.strip()

    print("Métricas de entrenamiento completadas:")
    # Muestra las últimas filas del DataFrame para ver las métricas finales
    print(df_results.tail())
# Out:
# Métricas de entrenamiento completadas:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 5      6  348.149         0.62970         0.33365         0.78549
# 6      7  400.771         0.60112         0.31655         0.78390
# 7      8  453.348         0.57391         0.30118         0.78204
# 8      9  509.248         0.55311         0.28790         0.78068
# 9     10  563.207         0.53119         0.27323         0.77936
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 5               0.97232            0.84508           0.92622
# 6               0.97262            0.85288           0.92461
# 7               0.97651            0.86268           0.94055
# 8               0.97040            0.84788           0.92935
# 9               0.97457            0.85230           0.93070
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 5              0.79039       0.58643       0.33194       0.78342  0.001010
# 6              0.79290       0.54509       0.31945       0.77567  0.000812
# 7              0.82708       0.50087       0.28941       0.77615  0.000614
# 8              0.81775       0.49984       0.28527       0.77576  0.000416
# 9              0.82201       0.48883       0.27836       0.77562  0.000218
#
#      lr/pg1    lr/pg2
# 5  0.001010  0.001010
# 6  0.000812  0.000812
# 7  0.000614  0.000614
# 8  0.000416  0.000416
# 9  0.000218  0.000218

# %%
   # --- Visualización de las métricas (opcional, pero muy útil) ---
if os.path.exists(results_path):
# --- Visualización de las métricas (opcional, pero muy útil) ---
    fig1 = plt.figure(figsize=(12, 6)) # Asigna la figura a una variable

    # Graficar mAP@0.50
    if 'metrics/mAP50(B)' in df_results.columns:
        plt.plot(df_results['epoch'], df_results['metrics/mAP50(B)'], label='mAP@0.50', marker='o', markersize=4)
    else:
        print("La columna 'metrics/mAP50(B)' no se encontró en los resultados.")

    # Graficar mAP@0.50-0.95
    if 'metrics/mAP50-95(B)' in df_results.columns:
        plt.plot(df_results['epoch'], df_results['metrics/mAP50-95(B)'], label='mAP@0.50-0.95', marker='x', markersize=4)
    else:
        print("La columna 'metrics/mAP50-95(B)' no se encontró en los resultados.")

    plt.title('Curva de mAP durante el Entrenamiento')
    plt.xlabel('Época')
    plt.ylabel('mAP')
    plt.grid(True)
    plt.legend()
    plt.show() # Intenta mostrar el gráfico

    # Guarda la primera figura después de intentar mostrarla
    save_path_map = os.path.join(os.path.dirname(results_path), 'map_curve.png')
    fig1.savefig(save_path_map)
    print(f"Gráfico de mAP guardado en: {save_path_map}")
    plt.close(fig1) # Cierra la figura para liberar memoria


    fig2 = plt.figure(figsize=(12, 6)) # Asigna la segunda figura a una variable
    # Graficar la pérdida de entrenamiento y validación
    if 'train/box_loss' in df_results.columns and 'val/box_loss' in df_results.columns:
        plt.plot(df_results['epoch'], df_results['train/box_loss'], label='Pérdida de Bounding Box (Entrenamiento)')
        plt.plot(df_results['epoch'], df_results['val/box_loss'], label='Pérdida de Bounding Box (Validación)')
    else:
        print("Las columnas de pérdida ('train/box_loss' o 'val/box_loss') no se encontraron en los resultados.")

    plt.title('Curvas de Pérdida durante el Entrenamiento')
    plt.xlabel('Época')
    plt.ylabel('Pérdida')
    plt.grid(True)
    plt.legend()
    plt.show() # Intenta mostrar el segundo gráfico

    # Guarda la segunda figura después de intentar mostrarla
    save_path_loss = os.path.join(os.path.dirname(results_path), 'loss_curve.png')
    fig2.savefig(save_path_loss)
    print(f"Gráfico de pérdidas guardado en: {save_path_loss}")
    plt.close(fig2) # Cierra la figura
# Out:
# Gráfico de mAP guardado en: C:/Users/Andres/runs/detect/train10\map_curve.png
# Gráfico de pérdidas guardado en: C:/Users/Andres/runs/detect/train10\loss_curve.png
